# %% [markdown]
# # DS-SF-36 | 03 | `pandas` | Codealong | Starter Code

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable)

# %% [markdown]
# ## Part A | Introduction to `pandas`

# %%
import os  

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
# !pwd   ###where am i?
# Out:
# /Users/nikka.keivanfar/DS-SF-36/classes/03/notebooks

# %%
# !ls ../datasets
# Out:
# dataset-03-bistro.csv              dataset-03-zillow-transactions.csv
# dataset-03-zillow-properties.csv

# %%
# !ls
# Out:
# assignment-03-pandas-starter-code-RyanK practice renaming.ipynb
# assignment-03-pandas-starter-code.ipynb
# codealong-03-pandas-starter-code-RyanK practice.ipynb
# codealong-03-pandas-starter-code.ipynb

# %%
# !ls
# Out:
# assignment-03-pandas-starter-code-RyanK practice renaming.ipynb
# assignment-03-pandas-starter-code.ipynb
# codealong-03-pandas-starter-code-RyanK practice.ipynb
# codealong-03-pandas-starter-code.ipynb

# %%
# !cat ../datasets/dataset-03-zillow-properties.csv   ###cat = show me contents of this file
# Out:
# "ID","Address","Latitude","Longitude","IsAStudio","Beds","Baths","Size","SizeUnit","LotSize","LotSizeUnit","BuiltInYear"
# 2121978635,"829 Folsom St UNIT 906, San Francisco, CA",37781429,-122401860,False,1.0,1.0,557.0,"sqft","","",2010.0
# 89239580,"690 Market St UNIT 1705, San Francisco, CA",37788246,-122403198,False,2.0,2.0,1050.0,"sqft","","",2007.0
# 15131782,"401 Grand View Ave APT 3, San Francisco, CA",37752157,-122442356,False,2.0,2.0,937.0,"sqft","","",1983.0
# 15179502,"250 Concord St, San Francisco, CA",37710141,-122442063,False,4.0,3.0,1574.0,"sqft",1947.0,"sqft",1959.0
# 52266124,"88 King St APT 317, San Francisco, CA",37780630,-122389635,False,2.0,2.0,1205.0,"sqft","","",2000.0
# 2100994004,"409 Miguel St, San Francisco, CA",37736625,-122427008,False,1.0,1.0,400.0,"sqft","","",""
# 15067755,"1250 Clay St APT 306, San Francisco, CA",37793575,-122413670,False,1.0,1.0,541.0,"sqft","","",1950.0
# 15112556,"1819 26th Ave, San Francisco, CA",37753480,-122484273,False,2.0,1.0,1175.0,"sqft",2996.0,"sqft",1939.0
# 15133321,"365 Magellan Ave, San Francisco, CA",37744952,-122463110,False,5.0,3.5,3094.0,"sqft",3920.0,"sqft",1926.0
# 61288341,"710 Masonic Ave, San Francisco, CA",37774719,-122445912,False,2.0,1.0,1405.0,"sqft","","",1914.0
# 15163807,"554 Anderson St, San Francisco, CA",37736454,-122415593,False,2.0,1.0,1015.0,"sqft",1751.0,"sqft",1910.0
# 15180778,"3709 25th St, San Francisco, CA",37750214,-122423153,False,2.0,1.0,1160.0,"sqft",750.0,"sqft",1925.0
# 79844821,"638 19th St UNIT 10, San Francisco, CA",37762084,-122389007,False,3.0,2.5,1467.0,"sqft","","",2007.0
# 15115459,"2076 14th Ave, San Francisco, CA",37749428,-122470497,False,2.0,1.0,1374.0,"sqft",3484.0,"sqft",1941.0
# 15183957,"112 Chenery St, San Francisco, CA",37739540,-122425828,False,3.0,2.0,1235.0,"sqft",1742.0,"sqft",1927.0
# 15072153,"1353 Green St, San Francisco, CA",37797685,-122421335,False,2.0,2.0,1764.0,"sqft","","",1941.0
# 119685526,"1902 Filbert St, San Francisco, CA",37798831,-122431053,False,1.0,2.0,1000.0,"sqft","","",1920.0
# 15099711,"886 30th Ave, San Francisco, CA",37772625,-122489280,False,2.0,3.0,1990.0,"sqft",2375.0,"sqft",1929.0
# 15065946,"44 Macondray Ln APT 2E, San Francisco, CA",37799474,-122414835,False,2.0,2.0,1165.0,"sqft","","",1980.0
# 15076711,"1 Daniel Burnham Ct APT 1404, San Francisco, CA",37786755,-122422500,False,2.0,2.0,1009.0,"sqft","","",1988.0
# 15068514,"1177 California St APT 702, San Francisco, CA",37791089,-122413658,False,1.0,1.0,511.0,"sqft","","",1978.0
# 15161351,"157 Winfield St, San Francisco, CA",37742237,-122418547,True,"","",1375.0,"sqft",1742.0,"sqft",1907.0
# 15133668,"815 Laguna Honda Blvd, San Francisco, CA",37743955,-122456084,False,2.0,1.5,1791.0,"sqft",3345.0,"sqft",1935.0
# 15133807,"644 Laguna Honda Blvd, San Francisco, CA",37745140,-122457306,False,"",2.5,1945.0,"sqft",3685.0,"sqft",1927.0
# 111932542,"1355 Pacific Ave UNIT 403, San Francisco, CA",37795295,-122417541,False,1.0,1.0,880.0,"sqft","","",2010.0
# 79846666,"555 4th St UNIT 513, San Francisco, CA",37779422,-122396712,False,2.0,2.0,1177.0,"sqft","","",2006.0
# 15070544,"1051-1053 Francisco St, San Francisco, CA",37803239,-122422458,False,5.0,6.0,4650.0,"sqft",4726.0,"sqft",1953.0
# 15080315,"2953 Broderick St, San Francisco, CA",37797633,-122444344,False,2.0,2.5,1876.0,"sqft",1637.0,"sqft",1923.0
# 69817957,"767 Bryant St APT 407, San Francisco, CA",37776354,-122401570,False,1.0,2.0,908.0,"sqft","","",2002.0
# 15063505,"740 Francisco St, San Francisco, CA",37804420,-122417389,False,"",2.0,1430.0,"sqft",2435.0,"sqft",1948.0
# 80752101,"60 Rausch St APT 401, San Francisco, CA",37776125,-122409677,False,3.0,2.5,1703.0,"sqft","","",2002.0
# 61288494,"400 Alemany Blvd APT 12, San Francisco, CA",37733174,-122414551,False,2.0,1.5,1048.0,"sqft","","",2003.0
# 15191204,"56 Restani Way, San Francisco, CA",37718088,-122443457,False,"",2.0,1540.0,"sqft",2356.0,"sqft",1954.0
# 80730869,"260 King St UNIT 817, San Francisco, CA",37777191,-122393394,False,"",1.0,759.0,"sqft","","",2004.0
# 15149005,"251-253 Missouri St, San Francisco, CA",37763202,-122396270,False,7.0,6.0,2904.0,"sqft",2482.0,"sqft",1900.0
# 64971857,"1436 Vallejo St, San Francisco, CA",37797200,-122421035,False,"",5.0,4554.0,"sqft",1920.0,"sqft",1925.0
# 2100695466,"980 Baker St APT 3, San Francisco, CA",37780437,-122441474,False,3.0,2.0,1758.0,"sqft","","",1961.0
# 15143661,"2253-2255 15TH St, San Francisco, CA",37765546,-122434375,False,"",2.0,2088.0,"sqft",4312.0,"sqft",1905.0
# 123174799,"1080 Sutter St APT 1003, San Francisco, CA",37788066,-122418065,False,2.0,1.0,753.0,"sqft","","",2013.0
# 15124706,"2647 43rd Ave, San Francisco, CA",37737279,-122501408,False,3.0,2.0,1232.0,"sqft",2996.0,"sqft",1948.0
# 15111963,"870 Pacheco St, San Francisco, CA",37754014,-122469527,False,3.0,4.0,1983.0,"sqft",3798.0,"sqft",1940.0
# 2126960082,"355 1st St UNIT 1905, San Francisco, CA",37787029,-122393638,False,1.0,1.0,691.0,"sqft","","",2004.0
# 15195766,"297 Sagamore St, San Francisco, CA",37711162,-122462003,"","","","","","","",""
# 59779139,"2020 Stockton St, San Francisco, CA",37804563,-122409793,False,3.0,2.0,1786.0,"sqft","","",1952.0
# 15120641,"2340 29th Ave, San Francisco, CA",37743660,-122486153,False,4.0,2.0,1805.0,"sqft",3484.0,"sqft",1927.0
# 79844263,"555 4th St, San Francisco, CA",37779422,-122396712,False,1.0,1.0,670.0,"sqft",1.0,"ac",2006.0
# 80749465,"16 Jennifer Pl, San Francisco, CA",37780017,-122402328,False,2.0,"",1367.0,"sqft","","",2000.0
# 15090783,"326 29th Ave, San Francisco, CA",37783151,-122488922,False,3.0,1.0,1675.0,"sqft",3049.0,"sqft",1910.0
# 15134585,"132 Marietta Dr, San Francisco, CA",37740617,-122448119,False,2.0,1.0,750.0,"sqft",2613.0,"sqft",1943.0
# 15185372,"2711 Diamond St, San Francisco, CA",37735889,-122434112,False,"",1.0,1022.0,"sqft",2012.0,"sqft",1900.0
# 15137378,"287 Brentwood Ave, San Francisco, CA",37732494,-122460211,False,4.0,4.5,4544.0,"sqft",6098.0,"sqft",1927.0
# 15131271,"681 Panorama Dr, San Francisco, CA",37753465,-122452131,False,3.0,2.0,1237.0,"sqft",3049.0,"sqft",1957.0
# 15124281,"2559 44th Ave, San Francisco, CA",37738891,-122502597,False,2.0,1.0,1214.0,"sqft",3000.0,"sqft",1945.0
# 15152280,"2127 24th St, San Francisco, CA",37753090,-122401105,False,"",1.0,1345.0,"sqft","","",1900.0
# 89239837,"338 Spear St UNIT 10B, San Francisco, CA",37789533,-122390371,False,2.0,2.0,1316.0,"sqft","","",2009.0
# 15184648,"2563 Diamond St, San Francisco, CA",37737921,-122434410,False,3.0,2.0,1885.0,"sqft",2500.0,"sqft",1950.0
# 15125990,"2754 39th Ave, San Francisco, CA",37735490,-122496329,False,3.0,2.0,1350.0,"sqft",3000.0,"sqft",1948.0
# 15125727,"496 Crestlake Dr, San Francisco, CA",37735772,-122489950,False,4.0,4.0,3085.0,"sqft",7426.0,"sqft",1931.0
# 2102906272,"444 Linden St, San Francisco, CA",37776170,-122425300,"","","","","","","",""
# 15134945,"27 Gaviota Way, San Francisco, CA",37739232,-122447580,False,3.0,3.0,2155.0,"sqft",2526.0,"sqft",1942.0
# 15182288,"74 Newburg St, San Francisco, CA",37745818,-122434713,False,4.0,2.0,1625.0,"sqft",1598.0,"sqft",1941.0
# 15196864,"20 Rossmoor Dr, San Francisco, CA",37730314,-122473000,False,3.0,2.5,2076.0,"sqft",3311.0,"sqft",1939.0
# 15090866,"323-325 25TH Ave, San Francisco, CA",37783380,-122485309,False,2.0,1.0,3130.0,"sqft",2996.0,"sqft",1923.0
# 15104925,"1459 31st Ave, San Francisco, CA",37760017,-122490103,False,4.0,2.0,2281.0,"sqft",3001.0,"sqft",1937.0
# 15149654,"1324 20th St, San Francisco, CA",37760291,-122394893,False,2.0,1.0,1000.0,"sqft",1646.0,"sqft",1925.0
# 15103550,"1394-1396 34TH Ave, San Francisco, CA",37761142,-122492858,False,"",2.0,2024.0,"sqft",1437.0,"sqft",1946.0
# 15124522,"2646-2648 Great Hwy, San Francisco, CA",37737392,-122506065,False,4.0,2.0,2550.0,"sqft",2674.0,"sqft",1948.0
# 15173423,"187 Tucker Ave, San Francisco, CA",37716222,-122407819,False,3.0,1.0,1060.0,"sqft",2500.0,"sqft",1949.0
# 15120712,"2343 30th Ave, San Francisco, CA",37743553,-122487877,False,2.0,1.0,1340.0,"sqft",3049.0,"sqft",1938.0
# 15183874,"126-128 Randall St, San Francisco, CA",37739965,-122426166,False,5.0,4.0,2430.0,"sqft",2500.0,"sqft",1986.0
# 64972332,"499 33rd Ave APT 103, San Francisco, CA",37779990,-122493690,False,2.0,2.0,1375.0,"sqft","","",2004.0
# 15131869,"1950 8th Ave, San Francisco, CA",37751815,-122463924,False,4.0,4.0,3673.0,"sqft",7775.0,"sqft",1925.0
# 64972342,"499 33rd Ave APT 310, San Francisco, CA",37779990,-122493690,False,3.0,"",1751.0,"sqft","","",2004.0
# 15119410,"2223 27th Ave, San Francisco, CA",37745903,-122484820,False,3.0,2.0,2378.0,"sqft",3001.0,"sqft",1940.0
# 124397860,"2200 Market St APT 202, San Francisco, CA",37765724,-122431383,False,1.0,1.5,916.0,"sqft","","",2014.0
# 15149594,"730-732 Tennessee St, San Francisco, CA",37762502,-122389995,False,"",2.0,2270.0,"sqft",2495.0,"sqft",1900.0
# 15147178,"456 Elizabeth St, San Francisco, CA",37752523,-122431083,False,2.0,2.0,1410.0,"sqft",2905.0,"sqft",1934.0
# 80732939,"125 Gilbert St APT 17, San Francisco, CA",37773223,-122401916,False,1.0,1.5,1047.0,"sqft","","",1996.0
# 15188349,"1988 Alemany Blvd, San Francisco, CA",37720440,-122439690,False,3.0,1.0,1466.0,"sqft",1646.0,"sqft",1939.0
# 15199248,"135 Red Rock Way APT 112L, San Francisco, CA",37746221,-122441968,False,1.0,1.0,830.0,"sqft","","",1972.0
# 15124103,"2514 40th Ave, San Francisco, CA",37739858,-122497704,False,3.0,2.0,1490.0,"sqft",3049.0,"sqft",1945.0
# 15156497,"1455 Oakdale Ave, San Francisco, CA",37732869,-122387815,False,5.0,3.0,1594.0,"sqft",2495.0,"sqft",1964.0
# 15146666,"979 Dolores St, San Francisco, CA",37753745,-122424926,False,3.0,2.0,1405.0,"sqft","","",1907.0
# 2101331127,"1408 31st Ave APT 303, San Francisco, CA",37760994,-122489700,False,2.0,2.0,1424.0,"sqft","","",2008.0
# 119685789,"1268 Dolores St, San Francisco, CA",37749056,-122425024,False,2.0,2.0,1850.0,"sqft","","",2012.0
# 59700180,"3316 California St APT 3, San Francisco, CA",37787260,-122449170,False,4.0,3.0,1779.0,"sqft","","",2000.0
# 15114102,"1922 42nd Ave, San Francisco, CA",37750815,-122500625,False,2.0,1.0,1076.0,"sqft",3000.0,"sqft",1952.0
# 15164199,"501 Crescent Ave, San Francisco, CA",37735041,-122416045,True,"","",960.0,"sqft",1751.0,"sqft",1905.0
# 15163943,"580 Prentiss St, San Francisco, CA",37736075,-122412513,False,2.0,1.0,918.0,"sqft",1750.0,"sqft",1951.0
# 96043590,"300 Berry St UNIT 720, San Francisco, CA",37773929,-122396240,False,1.0,1.0,659.0,"sqft","","",2008.0
# 15155751,"1546 Innes Ave, San Francisco, CA",37739068,-122387681,False,2.0,2.0,1629.0,"sqft",2500.0,"sqft",1938.0
# 15163518,"201 Holly Park Cir, San Francisco, CA",37737764,-122418634,False,3.0,2.0,2250.0,"sqft",1712.0,"sqft",1910.0
# 123597964,"829 Folsom St UNIT 906, San Francisco, CA",37781154,-122401649,False,"","",557.0,"sqft","","",2010.0
# 15127442,"300 Castro St, San Francisco, CA",37763918,-122435614,False,4.0,3.0,2451.0,"sqft",4691.0,"sqft",1900.0
# 15196201,"130 Shakespeare St, San Francisco, CA",37708635,-122462835,False,7.0,14.0,1308.0,"sqft",2500.0,"sqft",2015.0
# 15161805,"183 Bocana St, San Francisco, CA",37740976,-122417224,False,"",1.0,1275.0,"sqft",2500.0,"sqft",1922.0
# 15182023,"1381 Sanchez St, San Francisco, CA",37747076,-122428941,False,4.0,3.0,2000.0,"sqft",1999.0,"sqft",1900.0
# 15081147,"2955 Pacific Ave, San Francisco, CA",37791900,-122443975,False,3.0,2.0,2160.0,"sqft","","",1995.0
# 15143800,"30 Abbey St, San Francisco, CA",37763451,-122427635,False,3.0,2.0,1115.0,"sqft","","",1900.0
# 15197241,"312 Stratford Dr, San Francisco, CA",37719559,-122473829,False,"",1.0,1287.0,"sqft",4342.0,"sqft",1941.0
# 79845444,"988 Fulton St APT 326, San Francisco, CA",37778057,-122432510,False,1.0,1.0,417.0,"sqft","","",1999.0
# 96023008,"397 Valley St, San Francisco, CA",37744121,-122430900,False,2.0,1.0,931.0,"sqft","","",1950.0
# 15074558,"2684-2686 Sacramento St, San Francisco, CA",37789686,-122437098,False,"","",2840.0,"sqft",2674.0,"sqft",1900.0
# 119685072,"574 Natoma St APT 302, San Francisco, CA",37779014,-122409446,True,"",1.0,370.0,"sqft","","",2012.0
# 15134804,"571 Myra Way, San Francisco, CA",37738625,-122450835,False,3.0,1.5,1460.0,"sqft",2169.0,"sqft",1949.0
# 15195952,"3089 San Jose Ave, San Francisco, CA",37709566,-122457217,False,"",1.0,1050.0,"sqft",1999.0,"sqft",1938.0
# 15200513,"155 Arbor St, San Francisco, CA",37736967,-122437193,False,3.0,1.0,1550.0,"sqft",2400.0,"sqft",1937.0
# 79846985,"555 4th St UNIT 728, San Francisco, CA",37779048,-122397178,False,1.0,1.0,671.0,"sqft","","",2006.0
# 2100784055,"55 1/2 Lucy St, San Francisco, CA",37729980,-122393157,False,2.0,1.0,1000.0,"sqft","","",""
# 15108109,"4116-4118 Moraga St, San Francisco, CA",37755014,-122507015,False,4.0,"",1460.0,"sqft",3049.0,"sqft",1910.0
# 15079269,"591-595 Waller St, San Francisco, CA",37770560,-122433330,False,"",7.0,7240.0,"sqft",2696.0,"sqft",1900.0
# 15184744,"2 College Ter, San Francisco, CA",37734448,-122425856,False,2.0,2.0,1606.0,"sqft",1716.0,"sqft",1915.0
# 15158058,"2015 Thomas Ave, San Francisco, CA",37734273,-122398821,False,3.0,1.0,1512.0,"sqft",2796.0,"sqft",1941.0
# 15170822,"445 Persia Ave, San Francisco, CA",37721458,-122432181,False,4.0,2.0,1435.0,"sqft",2613.0,"sqft",1955.0
# 15121661,"2471 43rd Ave, San Francisco, CA",37740591,-122501641,False,2.0,1.0,1275.0,"sqft",3000.0,"sqft",1940.0
# 15146597,"3615 22nd St, San Francisco, CA",37754704,-122428164,False,3.0,2.5,1519.0,"sqft","","",1911.0
# 15178123,"1143 Naples St, San Francisco, CA",37712673,-122436874,False,5.0,3.0,3034.0,"sqft",3049.0,"sqft",1920.0
# 15146014,"62-64 Fair Oaks St, San Francisco, CA",37755706,-122424652,False,"",2.0,1816.0,"sqft",2583.0,"sqft",1900.0
# 15162638,"116 Eugenia Ave, San Francisco, CA",37741436,-122420620,False,2.0,1.0,1075.0,"sqft",1751.0,"sqft",1900.0
# 15167131,"155 Somerset St, San Francisco, CA",37729580,-122408459,False,2.0,1.0,1550.0,"sqft",3000.0,"sqft",1937.0
# 79841626,"6542 Fulton St, San Francisco, CA",37771905,-122502038,False,2.0,1.0,994.0,"sqft","","",1937.0
# 119685425,"235 Waller St APT 5, San Francisco, CA",37771232,-122427551,"","","","","","","",""
# 15084949,"1912 Golden Gate Ave, San Francisco, CA",37778500,-122442563,False,3.0,2.0,1154.0,"sqft",3436.0,"sqft",1900.0
# 2099928615,"310 Carolina St UNIT 404, San Francisco, CA",37764669,-122400656,False,2.0,2.5,1243.0,"sqft","","",2015.0
# 15072997,"1896 Pacific Ave APT 802, San Francisco, CA",37794706,-122426347,False,2.0,2.5,2272.0,"sqft","","",1924.0
# 89236856,"1049 Dolores St APT 4, San Francisco, CA",37752658,-122424819,False,2.0,1.0,904.0,"sqft","","",1960.0
# 15144135,"3657-3661 17TH St, San Francisco, CA",37762719,-122427562,False,"",4.0,5720.0,"sqft",2495.0,"sqft",1907.0
# 15129033,"547 Oak Park Dr, San Francisco, CA",37756130,-122460657,False,2.0,2.0,1245.0,"sqft",3624.0,"sqft",1962.0
# 125156575,"1915 Diamond St, San Francisco, CA",37742141,-122435111,False,"",1.0,2200.0,"sqft",4316.0,"sqft",1910.0
# 15190222,"414 Shields St, San Francisco, CA",37718115,-122466560,False,2.0,1.0,781.0,"sqft",2495.0,"sqft",1946.0
# 15163654,"281 Richland Ave, San Francisco, CA",37735998,-122420814,False,3.0,2.0,1300.0,"sqft",1937.0,"sqft",1900.0
# 15195221,"124 Saint Charles Ave, San Francisco, CA",37711739,-122469627,False,3.0,2.0,1305.0,"sqft",3497.0,"sqft",1938.0
# 15187023,"501 Junipero Serra Blvd, San Francisco, CA",37728731,-122471256,False,4.0,2.0,2327.0,"sqft",9147.0,"sqft",1924.0
# 61325251,"18 Colonial Way APT 2, San Francisco, CA",37728700,-122440609,False,3.0,2.0,1640.0,"sqft","","",2003.0
# 67394949,"1452 Bush St UNIT 1, San Francisco, CA",37788838,-122421268,False,2.0,2.5,1176.0,"sqft","","",2004.0
# 15193859,"265 Minerva St, San Francisco, CA",37715491,-122461202,False,2.0,1.5,967.0,"sqft",3123.0,"sqft",1940.0
# 15134099,"521 Magellan Ave, San Francisco, CA",37744034,-122466614,False,2.0,1.0,1216.0,"sqft",3920.0,"sqft",1920.0
# 15064640,"1047-1049 Lombard St, San Francisco, CA",37801889,-122418704,True,"","",4102.0,"sqft",3049.0,"sqft",1948.0
# 15173186,"3524-3526 San Bruno Ave, San Francisco, CA",37717460,-122400260,False,5.0,2.0,2250.0,"sqft",1668.0,"sqft",1908.0
# 111710714,"723 Taylor St # 501, San Francisco, CA",37789192,-122412231,False,1.0,1.0,677.0,"sqft","","",2010.0
# 15079836,"2146 Bay St, San Francisco, CA",37802227,-122442439,False,2.0,4.5,1500.0,"sqft",3436.0,"sqft",1925.0
# 15191699,"55 Mount Vernon Ave, San Francisco, CA",37715268,-122443871,False,"",1.0,930.0,"sqft",1912.0,"sqft",1925.0
# 15169434,"184 London St, San Francisco, CA",37726328,-122432852,False,3.0,1.0,750.0,"sqft",2495.0,"sqft",1910.0
# 15120387,"2339 20th Ave, San Francisco, CA",37744092,-122477170,False,3.0,2.0,1425.0,"sqft",3000.0,"sqft",1924.0
# 15127373,"4 Ord Ct, San Francisco, CA",37763598,-122439848,False,2.0,2.0,1170.0,"sqft",1232.0,"sqft",1900.0
# 15151294,"2874 23rd St, San Francisco, CA",37754595,-122409835,False,"",1.0,1167.0,"sqft",2596.0,"sqft",1900.0
# 15146224,"419 Hill St, San Francisco, CA",37755283,-122430545,False,3.0,2.0,2000.0,"sqft",2848.0,"sqft",1908.0
# 15147528,"75 Folsom St APT 801, San Francisco, CA",37789800,-122389765,False,2.0,2.0,1287.0,"sqft","","",1991.0
# 15072128,"1438 Green St UNIT 5A, San Francisco, CA",37798116,-122422880,False,2.0,2.0,1206.0,"sqft","","",1998.0
# 15068592,"1177 California St APT 304, San Francisco, CA",37791089,-122413658,False,1.0,1.0,645.0,"sqft","","",1977.0
# 15125969,"2771 38th Ave, San Francisco, CA",37735233,-122495898,False,3.0,2.0,1655.0,"sqft",3001.0,"sqft",1948.0
# 15068039,"1170 Sacramento St APT 9B, San Francisco, CA",37792930,-122412195,False,2.0,2.0,1961.0,"sqft","","",1963.0
# 15148444,"38 Bryant St APT 606, San Francisco, CA",37787466,-122388980,False,1.0,1.0,582.0,"sqft","","",1994.0
# 69817917,"200 Brannan St APT 413, San Francisco, CA",37783594,-122390725,False,1.0,2.0,1048.0,"sqft","","",2004.0
# 2101116542,"2753 Bryant St, San Francisco, CA",37750270,-122408600,False,9.0,3.0,4005.0,"sqft","","",1900.0
# 2108546010,"1738 Lombard St APT 4, San Francisco, CA",37800910,-122430229,False,2.0,2.0,"","","","",2004.0
# 15156520,"1497 Palou Ave, San Francisco, CA",37732644,-122389092,False,4.0,3.0,1750.0,"sqft",2500.0,"sqft",1977.0
# 15142858,"46 Sanchez St, San Francisco, CA",37768490,-122431645,False,3.0,2.0,1515.0,"sqft","","",1906.0
# 89239642,"349 Frederick St, San Francisco, CA",37766586,-122449058,False,3.0,2.5,2084.0,"sqft","","",1900.0
# 15161653,"79 Bradford St, San Francisco, CA",37741748,-122409262,False,2.0,2.0,900.0,"sqft",1751.0,"sqft",1933.0
# 15184555,"382 Surrey St, San Francisco, CA",37735936,-122438508,False,3.0,2.5,1625.0,"sqft",2953.0,"sqft",1966.0
# 2102385068,"129 Central Ave, San Francisco, CA",37770870,-122443840,False,3.0,2.0,"","","","",1905.0
# 58532731,"239 Brannan St UNIT 8C, San Francisco, CA",37782575,-122390364,False,2.0,2.0,1321.0,"sqft","","",2002.0
# 89240177,"451 Kansas St UNIT 631, San Francisco, CA",37764080,-122403289,False,2.0,2.0,928.0,"sqft","","",2007.0
# 124426156,"2175 Quesada Ave #V, San Francisco, CA",37738178,-122400512,"","","","","",2495.0,"sqft",1900.0
# 15145308,"4121-4123 20TH St, San Francisco, CA",37757539,-122433070,False,4.0,2.0,2100.0,"sqft",2848.0,"sqft",1900.0
# 15135197,"280 Dalewood Way, San Francisco, CA",37738566,-122458678,False,3.0,2.5,1941.0,"sqft",3297.0,"sqft",1966.0
# 2099901370,"1326 Utah St, San Francisco, CA",37752640,-122405600,False,6.0,5.0,2861.0,"sqft","","",""
# 15140802,"528 Miramar Ave, San Francisco, CA",37726323,-122457891,False,2.0,1.0,1328.0,"sqft",3798.0,"sqft",1919.0
# 15150465,"825 Rhode Island St, San Francisco, CA",37759320,-122401735,False,4.0,3.5,2882.0,"sqft",2495.0,"sqft",1910.0
# 2099925746,"738 Long Bridge St #912, San Francisco, CA",37771790,-122394700,False,3.0,3.0,1961.0,"sqft","","",""
# 80732173,"2080 3rd St APT 8, San Francisco, CA",37763302,-122389100,False,1.0,2.0,998.0,"sqft","","",1998.0
# 15092065,"455 25th Ave APT 2, San Francisco, CA",37780970,-122485155,False,3.0,2.0,1287.0,"sqft","","",1996.0
# 80756614,"1011 23rd St APT 2, San Francisco, CA",37755031,-122390251,False,2.0,1.5,1223.0,"sqft","","",2000.0
# 15163205,"3942 Folsom St, San Francisco, CA",37737742,-122413610,False,3.0,2.5,860.0,"sqft",1742.0,"sqft",1908.0
# 67394883,"380 10th St UNIT 27, San Francisco, CA",37771683,-122411809,False,2.0,2.0,1305.0,"sqft","","",2004.0
# 15116499,"2047 44th Ave, San Francisco, CA",37748414,-122503266,False,2.0,1.0,1214.0,"sqft",2996.0,"sqft",1946.0
# 15197869,"151 Everglade Dr, San Francisco, CA",37731504,-122489116,False,3.0,3.0,1858.0,"sqft",3136.0,"sqft",1950.0
# 114317753,"301 Mission St APT 30F, San Francisco, CA",37790542,-122395927,False,2.0,2.0,1601.0,"sqft","","",2009.0
# 15091950,"333-337 20TH Ave, San Francisco, CA",37781556,-122479793,False,4.0,"",2600.0,"sqft",3000.0,"sqft",1907.0
# 69819708,"260 King St UNIT 421, San Francisco, CA",37777641,-122393417,False,1.0,1.0,695.0,"sqft","","",2004.0
# 2136213970,"1200 Gough St, San Francisco, CA",37784770,-122424100,False,1.0,1.0,900.0,"sqft","","",1966.0
# 15158124,"2058 Thomas Ave, San Francisco, CA",37735148,-122399495,False,2.0,1.0,1222.0,"sqft",1972.0,"sqft",1941.0
# 15134464,"634 Rockdale Dr, San Francisco, CA",37740939,-122450120,False,"",1.0,1150.0,"sqft",3310.0,"sqft",1930.0
# 2108411930,"3500 19th St, San Francisco, CA",37760100,-122422000,False,2.0,2.5,1500.0,"sqft","","",2013.0
# 123597388,"667 Shotwell St # A, San Francisco, CA",37757851,-122415629,False,1.0,1.0,1212.0,"sqft","","",1890.0
# 63153965,"163 Precita Ave, San Francisco, CA",37747528,-122417059,False,3.0,2.0,1290.0,"sqft","","",1900.0
# 15156770,"2179 Quesada Ave, San Francisco, CA",37738219,-122400582,False,"",1.0,"","",2495.0,"sqft",1900.0
# 69820035,"760 Treat Ave # 1, San Francisco, CA",37757970,-122413821,False,3.0,2.0,1275.0,"sqft","","",1900.0
# 15105664,"1444 17th Ave # 101, San Francisco, CA",37760979,-122474469,False,3.0,3.0,1902.0,"sqft","","",1996.0
# 82786028,"425 1st St UNIT 802, San Francisco, CA",37786041,-122392654,False,2.0,2.0,1309.0,"sqft","","",2008.0
# 82785952,"2 Mint Plz STE 401, San Francisco, CA",37783241,-122407350,False,2.0,2.0,1245.0,"sqft","","",2009.0
# 15153012,"118 Jerrold Ave, San Francisco, CA",37728539,-122371160,False,3.0,2.0,1325.0,"sqft","","",1989.0
# 15064295,"111 Chestnut St APT 702, San Francisco, CA",37804240,-122405509,False,2.0,2.0,1033.0,"sqft","","",1993.0
# 69819845,"260 King St UNIT 769, San Francisco, CA",37777191,-122393394,False,1.0,1.0,748.0,"sqft","","",2004.0
# 53734143,"2013 Buchanan St, San Francisco, CA",37788841,-122430713,False,3.0,2.0,2100.0,"sqft",2328.0,"sqft",1999.0
# 63197193,"3345 17th St APT 5, San Francisco, CA",37763146,-122420502,False,1.0,2.0,878.0,"sqft","","",2002.0
# 15108159,"4036 Moraga St, San Francisco, CA",37755048,-122506217,False,2.0,1.0,850.0,"sqft",2495.0,"sqft",1941.0
# 15199198,"215 Red Rock Way APT 306J, San Francisco, CA",37745639,-122442432,False,1.0,1.0,744.0,"sqft","","",1972.0
# 15093075,"539 44th Ave, San Francisco, CA",37778322,-122505364,False,2.0,1.0,1290.0,"sqft",3000.0,"sqft",1922.0
# 55004355,"530 Chestnut St APT 407, San Francisco, CA",37804334,-122412450,False,2.0,2.0,1208.0,"sqft","","",2001.0
# 15164191,"650 Anderson St, San Francisco, CA",37735368,-122415694,False,"",1.0,1000.0,"sqft",1751.0,"sqft",1927.0
# 15137489,"1100 Monterey Blvd, San Francisco, CA",37730397,-122460959,False,4.0,3.5,2562.0,"sqft",4700.0,"sqft",1930.0
# 2101167573,"1340 Union St, San Francisco, CA",37798930,-122421388,False,2.0,2.0,1108.0,"sqft","","",1951.0
# 80748857,"999 16th St APT 17, San Francisco, CA",37766197,-122396560,False,1.0,1.5,1140.0,"sqft","","",1998.0
# 15192647,"2670 San Jose Ave, San Francisco, CA",37714831,-122451887,False,3.0,1.0,1001.0,"sqft",2613.0,"sqft",1949.0
# 80746693,"142 Russ St APT 4, San Francisco, CA",37778152,-122407806,False,3.0,2.5,2326.0,"sqft","","",1999.0
# 15168015,"180 Vienna St, San Francisco, CA",37725652,-122426836,False,"",1.0,432.0,"sqft",2495.0,"sqft",1904.0
# 15168244,"332 Gambier St, San Francisco, CA",37725141,-122421470,False,3.0,1.0,1435.0,"sqft",2996.0,"sqft",1910.0
# 2099751356,"551 Hudson Ave #202, San Francisco, CA",37731700,-122374000,False,1.0,1.0,788.0,"sqft","","",""
# 15081736,"3515 Washington St, San Francisco, CA",37789217,-122450906,False,2.0,3.0,2760.0,"sqft",4464.0,"sqft",1941.0
# 15191082,"378 Mount Vernon Ave, San Francisco, CA",37718357,-122447720,False,2.0,1.0,1210.0,"sqft",2199.0,"sqft",1939.0
# 15068874,"1001 Pine St APT 801, San Francisco, CA",37790348,-122412568,False,"",1.0,650.0,"sqft","","",1963.0
# 116157280,"830 Alabama St # B, San Francisco, CA",37758160,-122411765,False,3.0,2.0,1853.0,"sqft","","",1900.0
# 116157304,"1480 Golden Gate Ave, San Francisco, CA",37779426,-122434875,False,4.0,2.5,2151.0,"sqft","","",1900.0
# 2121221385,"925 Larkin St, San Francisco, CA",37786427,-122418222,False,"","",6600.0,"sqft","","",1907.0
# 15094548,"528 2nd Ave, San Francisco, CA",37778685,-122459484,True,"","",2810.0,"sqft",3049.0,"sqft",1906.0
# 15093745,"591 27th Ave, San Francisco, CA",37778299,-122486969,False,2.0,1.0,900.0,"sqft",1760.0,"sqft",1915.0
# 15069628,"47-49 Casa Way, San Francisco, CA",37805371,-122439029,False,3.0,"",3905.0,"sqft",2748.0,"sqft",1939.0
# 15185003,"283 Bemis St, San Francisco, CA",37735807,-122432190,False,4.0,3.0,2020.0,"sqft",2500.0,"sqft",1938.0
# 80738981,"400 Beale St APT 1308, San Francisco, CA",37786910,-122390925,False,1.0,1.0,680.0,"sqft","","",2002.0
# 15186444,"80 Danton St, San Francisco, CA",37731080,-122432626,False,3.0,3.0,2000.0,"sqft",2500.0,"sqft",1906.0
# 2100831589,"181 Noe St, San Francisco, CA",37766201,-122433226,False,3.0,1.0,"","","","",""
# 15124603,"2627 45th Ave, San Francisco, CA",37737526,-122503577,False,3.0,2.0,1400.0,"sqft",2996.0,"sqft",1937.0
# 15148821,"354-358 Utah St, San Francisco, CA",37765066,-122406787,False,5.0,3.0,4350.0,"sqft",2500.0,"sqft",1908.0
# 15131253,"333 Dellbrook Ave, San Francisco, CA",37752037,-122452846,False,2.0,1.0,1054.0,"sqft",4412.0,"sqft",1957.0
# 15188851,"154 Tara St, San Francisco, CA",37720786,-122449193,False,4.0,3.0,1100.0,"sqft",2600.0,"sqft",1940.0
# 15170571,"182 Prague St, San Francisco, CA",37719320,-122427198,False,2.0,1.0,1125.0,"sqft",1742.0,"sqft",1930.0
# 15066201,"1101 Green St # 303, San Francisco, CA",37798234,-122417394,False,2.0,1.0,1003.0,"sqft","","",1930.0
# 15151407,"1052 Rhode Island St, San Francisco, CA",37756432,-122402082,False,"",1.0,1080.0,"sqft",2495.0,"sqft",1927.0
# 15172689,"1015 Goettingen St, San Francisco, CA",37719474,-122403272,False,3.0,2.0,1500.0,"sqft",1751.0,"sqft",1954.0
# 15133540,"15 Teresita Blvd APT 14, San Francisco, CA",37745036,-122451740,False,2.0,2.0,886.0,"sqft","","",1990.0
# 15193738,"400 Head St, San Francisco, CA",37714440,-122464169,False,2.0,1.0,1162.0,"sqft",1742.0,"sqft",1946.0
# 80732028,"83 Lafayette St APT 4, San Francisco, CA",37772805,-122416538,False,1.0,1.0,1008.0,"sqft","","",1993.0
# 15073657,"1895 Pacific Ave APT 506, San Francisco, CA",37794168,-122426243,False,1.0,1.0,1165.0,"sqft","","",1931.0
# 15077111,"1200 Gough St APT 22B, San Francisco, CA",37784820,-122423994,True,"",1.0,550.0,"sqft","","",1966.0
# 53734188,"2409 Scott St APT 2, San Francisco, CA",37792297,-122439897,False,1.0,1.0,1135.0,"sqft","","",1904.0
# 15103440,"1363 31st Ave, San Francisco, CA",37761810,-122490230,False,3.0,2.0,1822.0,"sqft",3000.0,"sqft",1940.0
# 67394607,"200 Townsend St UNIT 45, San Francisco, CA",37778904,-122393325,False,1.0,2.0,856.0,"sqft","","",2003.0
# 15101712,"1216 28th Ave, San Francisco, CA",37764647,-122486547,False,5.0,2.5,2666.0,"sqft",4791.0,"sqft",1924.0
# 15174292,"51 Peabody St, San Francisco, CA",37711481,-122406571,False,"",2.0,1525.0,"sqft",2639.0,"sqft",1940.0
# 15161660,"73 Carver St, San Francisco, CA",37742053,-122409855,False,3.0,2.0,1325.0,"sqft",1750.0,"sqft",1951.0
# 15104496,"1422 42nd Ave, San Francisco, CA",37760143,-122501274,False,3.0,1.0,1325.0,"sqft",2996.0,"sqft",1951.0
# 15143292,"1839 15th St APT 356, San Francisco, CA",37765474,-122424915,False,1.0,1.0,897.0,"sqft","","",1983.0
# 2114498518,"201 Sansome St UNIT 501, San Francisco, CA",37792255,-122401245,False,1.0,1.0,658.0,"sqft","","",1909.0
# 15157208,"1574 Shafter Ave, San Francisco, CA",37730968,-122390069,False,"",1.0,1422.0,"sqft",2495.0,"sqft",1921.0
# 15141526,"220 San Benito Way, San Francisco, CA",37732698,-122467210,False,4.0,2.5,1941.0,"sqft",3846.0,"sqft",1922.0
# 15063609,"819 Francisco St, San Francisco, CA",37803728,-122419055,False,2.0,3.5,2040.0,"sqft",3920.0,"sqft",1976.0
# 15160348,"249 Mullen Ave, San Francisco, CA",37746969,-122407362,False,2.0,2.0,1275.0,"sqft",1746.0,"sqft",1907.0
# 59700239,"1588 Waller St, San Francisco, CA",37768755,-122450275,False,2.0,1.0,1070.0,"sqft","","",1908.0
# 15121139,"2339 41st Ave, San Francisco, CA",37743033,-122499663,False,"",3.0,2250.0,"sqft",2996.0,"sqft",1967.0
# 19333808,"San Carlos St, Carmel, CA",37762245,-122420046,False,2.0,1.0,847.0,"sqft",4000.0,"sqft",1958.0
# 15077902,"601 Van Ness Ave APT 944, San Francisco, CA",37781386,-122421406,False,1.0,1.0,894.0,"sqft","","",1982.0
# 2100902229,"2299 Market St APT 502, San Francisco, CA",37764100,-122433000,False,1.0,1.0,700.0,"sqft","","",2013.0
# 15076450,"1483 Sutter St APT 1102, San Francisco, CA",37786750,-122424235,False,1.0,1.0,650.0,"sqft","","",1993.0
# 79846075,"1562 22nd St, San Francisco, CA",37757671,-122396586,False,3.0,2.0,2542.0,"sqft","","",2006.0
# 15199562,"404 Gold Mine Dr, San Francisco, CA",37739284,-122438555,False,4.0,3.0,2271.0,"sqft",2713.0,"sqft",1967.0
# 15157943,"15 Scotia Ave, San Francisco, CA",37734337,-122401708,False,3.0,2.0,1482.0,"sqft",2417.0,"sqft",1936.0
# 123596761,"643 Natoma St, San Francisco, CA",37777526,-122410789,False,2.0,1.0,830.0,"sqft","","",1910.0
# 15069276,"795 Sutter St # 303, San Francisco, CA",37788404,-122413260,False,3.0,2.0,1753.0,"sqft","","",1913.0
# 2099906560,"72 Townsend #502, San Francisco, CA",37781040,-122390100,False,2.0,2.0,1000.0,"sqft","","",""
# 63197592,"3021 20th St, San Francisco, CA",37758878,-122411147,False,1.0,2.0,1267.0,"sqft","","",1890.0
# 15153517,"19 Rebecca Ln, San Francisco, CA",37737383,-122382397,False,2.0,2.0,1210.0,"sqft",871.0,"sqft",1992.0
# 15090770,"2730-2732 Clement St, San Francisco, CA",37782092,-122488723,False,4.0,2.0,3040.0,"sqft",2538.0,"sqft",1924.0
# 80749447,"199 New Montgomery St UNIT 1201, San Francisco, CA",37786632,-122399101,False,2.0,2.0,971.0,"sqft","","",2004.0
# 15188382,"1145 Cayuga Ave, San Francisco, CA",37719885,-122441105,False,3.0,1.0,1590.0,"sqft",2178.0,"sqft",1941.0
# 64972695,"355 1st St UNIT 1702, San Francisco, CA",37787029,-122393600,False,2.0,2.0,1166.0,"sqft","","",2004.0
# 15159044,"2091 Bancroft Ave, San Francisco, CA",37730545,-122402057,False,4.0,3.0,2350.0,"sqft",2613.0,"sqft",1992.0
# 15139010,"2 Northwood Dr, San Francisco, CA",37729820,-122456873,False,3.0,2.0,1960.0,"sqft",5662.0,"sqft",1924.0
# 15150214,"2724 21st St, San Francisco, CA",37757795,-122409332,False,2.0,1.0,1250.0,"sqft",1698.0,"sqft",1900.0
# 61325028,"901 Post St # 2, San Francisco, CA",37787089,-122416761,False,3.0,2.0,1207.0,"sqft","","",2002.0
# 15180636,"1069 Capp St, San Francisco, CA",37749612,-122416789,True,"","",3140.0,"sqft",3737.0,"sqft",1900.0
# 15071199,"2374-2376 Greenwich St, San Francisco, CA",37798820,-122438743,False,4.0,5.0,4178.0,"sqft",2495.0,"sqft",1938.0
# 15095382,"559 21st Ave, San Francisco, CA",37777240,-122480556,False,2.0,1.0,1400.0,"sqft",3001.0,"sqft",1918.0
# 69819637,"260 King St UNIT 815, San Francisco, CA",37777641,-122393417,False,1.0,1.0,903.0,"sqft","","",2004.0
# 89239104,"301 Main St # IT5C, San Francisco, CA",37789333,-122391698,False,2.0,2.0,1752.0,"sqft","","",2008.0
# 89240348,"338 Spear St UNIT 39A, San Francisco, CA",37789533,-122390371,False,2.0,2.0,1300.0,"sqft","","",2009.0
# 15171058,"437 London St, San Francisco, CA",37722014,-122435432,False,2.0,1.0,900.0,"sqft",2495.0,"sqft",1925.0
# 15153995,"1480 Shafter Ave, San Francisco, CA",37729988,-122388333,False,2.0,1.0,952.0,"sqft",2613.0,"sqft",1926.0
# 15097709,"668 23rd Ave, San Francisco, CA",37775173,-122481902,False,"",1.0,1325.0,"sqft",2996.0,"sqft",1922.0
# 2100695464,"532 Lyon St, San Francisco, CA",37775802,-122442710,False,5.0,5.0,"","",3044.0,"sqft",1904.0
# 15137303,"22 Fernwood Dr, San Francisco, CA",37734117,-122461758,False,4.0,2.5,2090.0,"sqft",4103.0,"sqft",1931.0
# 15140890,"54 Marston Ave, San Francisco, CA",37727716,-122445802,False,5.0,5.0,2500.0,"sqft",2813.0,"sqft",1927.0
# 89239155,"1501 Greenwich St UNIT 403, San Francisco, CA",37800064,-122424682,False,2.0,2.0,1115.0,"sqft","","",2008.0
# 69819664,"260 King St UNIT 1205, San Francisco, CA",37777191,-122393394,False,2.0,2.0,1488.0,"sqft","","",2004.0
# 15069477,"631 Ofarrell St APT 816, San Francisco, CA",37785240,-122415125,True,"",1.0,480.0,"sqft","","",1930.0
# 89238407,"631 Folsom St APT 12B, San Francisco, CA",37784713,-122396873,False,2.0,2.0,1054.0,"sqft","","",2009.0
# 96048518,"16 Orizaba Ave, San Francisco, CA",37709894,-122462280,False,6.0,6.0,4136.0,"sqft",2613.0,"sqft",2010.0
# 15094244,"470 12th Ave, San Francisco, CA",37779375,-122470285,False,2.0,1.5,1630.0,"sqft","","",1931.0
# 15110595,"1727 34th Ave, San Francisco, CA",37754831,-122492968,False,3.0,2.0,1845.0,"sqft",3001.0,"sqft",1940.0
# 15196408,"2970 22nd Ave, San Francisco, CA",37733225,-122477613,False,5.0,4.0,2975.0,"sqft",4356.0,"sqft",1935.0
# 15107430,"1578 35th Ave, San Francisco, CA",37757673,-122493580,False,"",2.0,2301.0,"sqft",3267.0,"sqft",1932.0
# 64972712,"355 1st St UNIT S1905, San Francisco, CA",37787031,-122393642,False,1.0,1.0,691.0,"sqft","","",2004.0
# 2100791455,"130A Langton Street, San Francisco, CA",37776110,-122408270,False,2.0,1.5,1000.0,"sqft","","",1906.0
# 59779481,"2515 Lake St, San Francisco, CA",37785432,-122486556,False,3.0,3.0,2500.0,"sqft","","",1936.0
# 15096544,"783 La Playa St # 2, San Francisco, CA",37773690,-122510340,False,1.0,1.0,667.0,"sqft","","",1991.0
# 2131957929,"1821 Grant Ave, San Francisco, CA",37803760,-122408531,False,2.0,2.0,1048.0,"sqft","","",1975.0
# 2101588805,"82 Alvarado St, San Francisco, CA",37754504,-122422736,False,2.0,1.0,"","","","",""
# 15163177,"450 Prentiss St, San Francisco, CA",37737609,-122412376,False,2.0,1.0,1070.0,"sqft",1751.0,"sqft",1926.0
# 15065032,"101 Lombard St APT 116E, San Francisco, CA",37803470,-122404090,False,1.0,1.0,1000.0,"sqft","","",1983.0
# 15080826,"2780 Broadway St, San Francisco, CA",37793580,-122442803,False,5.0,6.0,6800.0,"sqft",3460.0,"sqft",1962.0
# 15075278,"2440 Bush St # C, San Francisco, CA",37786788,-122437531,False,3.0,2.5,1810.0,"sqft","","",1985.0
# 15160369,"123 Peralta Ave, San Francisco, CA",37747171,-122407400,False,2.0,1.0,800.0,"sqft",1750.0,"sqft",1908.0
# 15147990,"134 Langton St, San Francisco, CA",37775715,-122407900,False,2.0,1.5,1000.0,"sqft","","",1906.0
# 15152389,"1251-1253 Hampshire St, San Francisco, CA",37752069,-122406936,False,"",2.0,3020.0,"sqft",2500.0,"sqft",1925.0
# 15123561,"2555 28th Ave, San Francisco, CA",37739715,-122485461,False,4.0,2.0,1360.0,"sqft",3049.0,"sqft",1910.0
# 82785286,"181 Ofarrell St STE 514, San Francisco, CA",37786190,-122407630,False,1.0,1.5,1080.0,"sqft","","",2006.0
# 111934546,"301 Mission St APT 25B, San Francisco, CA",37790542,-122395919,False,1.0,1.0,668.0,"sqft","","",2009.0
# 15133056,"159 Glenview Dr, San Francisco, CA",37748824,-122447752,False,2.0,1.0,833.0,"sqft",3001.0,"sqft",1951.0
# 80744434,"950 Harrison St UNIT 101, San Francisco, CA",37778388,-122403190,False,3.0,2.0,1642.0,"sqft","","",2000.0
# 125115962,"1027 Clayton St # V, San Francisco, CA",37763458,-122447425,"","","","","",2247.0,"sqft",1900.0
# 123598014,"380 14th St APT 507, San Francisco, CA",37768220,-122421779,False,2.0,2.0,"","","","",2012.0
# 15172663,"50 Ankeny St, San Francisco, CA",37719098,-122404078,False,3.0,3.0,2264.0,"sqft",2614.0,"sqft",1976.0
# 15066344,"999 Green St APT 905, San Francisco, CA",37798451,-122415218,False,1.0,1.0,986.0,"sqft","","",1964.0
# 119685503,"829 Folsom St UNIT 412, San Francisco, CA",37781154,-122401649,False,"","",634.0,"sqft","","",2010.0
# 15145720,"956 S Van Ness Ave, San Francisco, CA",37757832,-122417139,False,4.0,4.0,3500.0,"sqft",4165.0,"sqft",1872.0
# 15150777,"540 Texas St, San Francisco, CA",37759462,-122395570,False,2.0,4.0,1700.0,"sqft",2700.0,"sqft",1926.0
# 15129565,"83 Seward St, San Francisco, CA",37758694,-122440807,False,3.0,2.0,2650.0,"sqft",2613.0,"sqft",1929.0
# 15076120,"2075 Sutter St APT 507, San Francisco, CA",37785647,-122434462,False,2.0,2.0,1084.0,"sqft","","",1992.0
# 15071070,"2701 Van Ness Ave APT 702, San Francisco, CA",37800573,-122424849,False,"",1.0,793.0,"sqft","","",1929.0
# 15100990,"4220 Irving St, San Francisco, CA",37762654,-122503312,False,3.0,2.0,1675.0,"sqft",2495.0,"sqft",1950.0
# 15165922,"95 Stoneyford Ave, San Francisco, CA",37729425,-122421110,False,3.0,2.0,1400.0,"sqft",2208.0,"sqft",1942.0
# 124852113,"501 Noriega St # V, San Francisco, CA",37754997,-122469024,"","","","","",3201.0,"sqft",1900.0
# 15082200,"333 Presidio Ave APT 4, San Francisco, CA",37788551,-122447336,False,1.0,1.0,770.0,"sqft","","",1907.0
# 15131186,"616 Panorama Dr, San Francisco, CA",37754174,-122451479,False,4.0,2.0,1931.0,"sqft",3998.0,"sqft",1957.0
# 15076699,"1 Daniel Burnham Ct APT 1202, San Francisco, CA",37786755,-122422500,False,1.0,1.0,772.0,"sqft","","",1988.0
# 15071012,"2701 Van Ness Ave APT 207, San Francisco, CA",37800573,-122424849,False,"",1.0,885.0,"sqft","","",1929.0
# 15165309,"676 Sweeny St, San Francisco, CA",37730425,-122416758,False,2.0,1.0,850.0,"sqft",2439.0,"sqft",1942.0
# 15124521,"27 Cutler Ave, San Francisco, CA",37736824,-122505856,False,4.0,3.0,1622.0,"sqft",2495.0,"sqft",1949.0
# 80742238,"2002 3rd St APT 213, San Francisco, CA",37763988,-122389167,False,2.0,2.0,1354.0,"sqft","","",2002.0
# 89239862,"901 Bush St APT 203, San Francisco, CA",37789520,-122412277,False,"","",429.0,"sqft","","",1909.0
# 64972890,"101 Crescent Way APT 2102, San Francisco, CA",37710918,-122389238,False,2.0,2.0,1063.0,"sqft","","",2001.0
# 15074306,"1950 Gough St APT 306, San Francisco, CA",37791558,-122425677,False,1.0,1.0,1000.0,"sqft","","",1926.0
# 80735046,"260 King St UNIT 703, San Francisco, CA",37777191,-122393394,False,2.0,2.0,1286.0,"sqft","","",2004.0
# 15071286,"3038 Pierce St, San Francisco, CA",37798140,-122438775,False,2.0,2.0,1150.0,"sqft","","",1906.0
# 15153753,"1311 Palou Ave, San Francisco, CA",37730765,-122385777,True,"","",2645.0,"sqft",4996.0,"sqft",1923.0
# 15085630,"650-652 Broderick St, San Francisco, CA",37776420,-122439479,False,8.0,2.0,3350.0,"sqft",2809.0,"sqft",1907.0
# 15198208,"447 Country Club Dr, San Francisco, CA",37730962,-122495345,False,3.0,1.75,1050.0,"sqft",3137.0,"sqft",1954.0
# 15149093,"548 Rhode Island St, San Francisco, CA",37762814,-122402695,False,2.0,1.0,1025.0,"sqft",2495.0,"sqft",1938.0
# 67394898,"8300 Oceanview Ter APT 306, San Francisco, CA",37710480,-122467645,False,1.0,1.0,745.0,"sqft","","",2002.0
# 2100643449,"2149 Lyon St APT 4, San Francisco, CA",37790535,-122446099,False,2.0,1.5,"","","","",1907.0
# 15159949,"256-258 Precita Ave, San Francisco, CA",37747136,-122414649,False,"",2.0,1700.0,"sqft",1873.0,"sqft",1910.0
# 15083161,"1825 Scott St, San Francisco, CA",37786681,-122438711,False,"",1.0,1100.0,"sqft",1694.0,"sqft",1900.0
# 15065727,"1360 Montgomery St APT 1, San Francisco, CA",37801802,-122404269,False,1.0,1.0,552.0,"sqft","","",1937.0
# 15094520,"3701 Geary Blvd # 304, San Francisco, CA",37780939,-122459167,False,2.0,2.0,1214.0,"sqft",8250.0,"sqft",1986.0
# 15138245,"154 Yerba Buena Ave, San Francisco, CA",37736032,-122462007,False,2.0,1.5,1700.0,"sqft",3963.0,"sqft",1922.0
# 15086718,"1260 Haight St APT 5, San Francisco, CA",37770785,-122443090,False,2.0,1.0,1082.0,"sqft",3438.0,"sqft",1928.0
# 15070728,"3315 Pierce St, San Francisco, CA",37800650,-122439786,False,3.0,3.5,2255.0,"sqft",2500.0,"sqft",1925.0
# 15113584,"1858 47th Ave, San Francisco, CA",37751825,-122506072,False,3.0,2.0,1135.0,"sqft",3000.0,"sqft",1958.0
# 15175282,"128-130 Cora St, San Francisco, CA",37711288,-122409324,False,2.0,2.0,832.0,"sqft",3646.0,"sqft",1917.0
# 15116598,"2007 46th Ave, San Francisco, CA",37749009,-122505371,False,3.0,2.0,1300.0,"sqft",1742.0,"sqft",1940.0
# 15186111,"106 Circular Ave, San Francisco, CA",37731109,-122438211,False,2.0,1.0,1064.0,"sqft",2178.0,"sqft",1941.0
# 15141807,"61 Pinehurst Way, San Francisco, CA",37727776,-122465400,False,5.0,3.0,2730.0,"sqft",3097.0,"sqft",1928.0
# 2100786271,"2149 Lyon St APT 1, San Francisco, CA",37790535,-122446099,False,2.0,1.0,"","","","",1907.0
# 89237920,"122 Maynard St, San Francisco, CA",37729094,-122427690,False,5.0,5.0,2700.0,"sqft",2750.0,"sqft",2009.0
# 80731709,"35 Lucerne St # C, San Francisco, CA",37773727,-122401537,False,"","",1446.0,"sqft","","",1997.0
# 15136326,"495 Los Palmos Dr, San Francisco, CA",37734290,-122452633,False,3.0,1.0,1300.0,"sqft",2774.0,"sqft",1947.0
# 119684869,"5900 3rd St UNIT 2219, San Francisco, CA",37725337,-122399307,False,2.0,2.0,1011.0,"sqft","","",2010.0
# 80742310,"400 Beale St APT 1407, San Francisco, CA",37786910,-122390925,False,2.0,2.0,1102.0,"sqft","","",2001.0
# 15140632,"154 Westwood Dr, San Francisco, CA",37728721,-122458881,False,3.0,2.0,1200.0,"sqft",4499.0,"sqft",1925.0
# 15143034,"66-70 Landers St, San Francisco, CA",37766736,-122428085,True,"","",3775.0,"sqft",3123.0,"sqft",1905.0
# 15066085,"1907 Leavenworth St APT 8, San Francisco, CA",37798645,-122417500,False,2.0,1.0,956.0,"sqft","","",1907.0
# 15102663,"1337-1339 8TH Ave, San Francisco, CA",37763311,-122465518,False,"",3.0,1800.0,"sqft",2996.0,"sqft",1912.0
# 15148222,"201 Harrison St APT 407, San Francisco, CA",37787585,-122390480,True,"",1.0,410.0,"sqft","","",1991.0
# 15138251,"1635 Plymouth Ave, San Francisco, CA",37731667,-122457878,False,4.0,3.0,2754.0,"sqft",5301.0,"sqft",1925.0
# 15106778,"1555 21st Ave, San Francisco, CA",37758688,-122479261,False,2.0,2.0,1204.0,"sqft",3049.0,"sqft",1926.0
# 2100831588,"164 Parker Ave # A, San Francisco, CA",37782512,-122454025,False,2.0,1.0,"","","","",""
# 15139810,"221 Flood Ave, San Francisco, CA",37729648,-122444867,False,9.0,6.0,5000.0,"sqft",2809.0,"sqft",1900.0
# 15134204,"80 Edgehill Way, San Francisco, CA",37742482,-122460233,False,4.0,4.0,3495.0,"sqft",5314.0,"sqft",1960.0
# 15117639,"2195 28th Ave, San Francisco, CA",37746487,-122485890,False,4.0,3.0,2260.0,"sqft",2375.0,"sqft",1939.0
# 121337574,"315 Arlington St, San Francisco, CA",37736404,-122427276,False,2.0,1.0,1147.0,"sqft","","",1910.0
# 15097178,"760 35th Ave, San Francisco, CA",37774688,-122494764,False,8.0,5.0,3905.0,"sqft",3598.0,"sqft",1965.0
# 15102698,"1310 10th Ave, San Francisco, CA",37763697,-122467077,False,3.0,3.0,1880.0,"sqft",2374.0,"sqft",1908.0
# 124891624,"2299 Market St APT 502, San Francisco, CA",37764138,-122433001,False,1.0,1.0,691.0,"sqft","","",2013.0
# 15088159,"1043-1045 Clayton St, San Francisco, CA",37763286,-122447391,False,"",4.0,5736.0,"sqft","","",1974.0
# 15132481,"48 Dellbrook Ave, San Francisco, CA",37749920,-122454366,False,2.0,1.0,1056.0,"sqft",4939.0,"sqft",1956.0
# 64969894,"140 S Van Ness Ave UNIT 1021, San Francisco, CA",37771585,-122418825,False,2.0,2.0,1160.0,"sqft","","",2002.0
# 35972022,"1101 Pacific Ave APT 302, San Francisco, CA",37795912,-122413603,False,2.0,2.0,1009.0,"sqft","","",2000.0
# 15134909,"450 Teresita Blvd, San Francisco, CA",37739963,-122448495,False,2.0,1.0,1464.0,"sqft",3920.0,"sqft",1939.0
# 15076978,"66 Cleary Ct APT 1408, San Francisco, CA",37784298,-122427058,False,2.0,2.0,1106.0,"sqft","","",1963.0
# 15170366,"558 Brussels St, San Francisco, CA",37725076,-122405063,False,"",2.0,1500.0,"sqft","","",1971.0
# 15139841,"179 Flood Ave, San Francisco, CA",37729648,-122443800,False,4.0,4.0,1900.0,"sqft",2809.0,"sqft",1924.0
# 15104164,"1440 La Playa St, San Francisco, CA",37759503,-122508756,False,3.0,2.0,1313.0,"sqft",2996.0,"sqft",1900.0
# 89240293,"338 Spear St UNIT 4C, San Francisco, CA",37789533,-122390371,False,1.0,1.0,799.0,"sqft","","",2009.0
# 15178486,"34 Pope St, San Francisco, CA",37714288,-122441638,False,4.0,3.0,2083.0,"sqft",3000.0,"sqft",1991.0
# 122063937,"724 Masonic Ave, San Francisco, CA",37774445,-122445869,False,2.0,1.0,1236.0,"sqft","","",1912.0
# 15185668,"130 Chilton Ave, San Francisco, CA",37733610,-122437073,False,2.0,1.0,728.0,"sqft",2500.0,"sqft",1925.0
# 15154657,"884 Ingerson Ave, San Francisco, CA",37718050,-122390617,False,5.0,3.0,1789.0,"sqft",2613.0,"sqft",1964.0
# 15066608,"455 Vallejo St APT 111, San Francisco, CA",37798796,-122404766,False,1.0,1.0,825.0,"sqft","","",1973.0
# 63197354,"765 Market St APT 31H, San Francisco, CA",37786220,-122404310,False,2.0,3.0,1434.0,"sqft","","",2001.0
# 63196600,"2032 Green St # B, San Francisco, CA",37796779,-122432659,False,"",1.0,950.0,"sqft","","",1900.0
# 15120436,"2375-2377 21ST Ave, San Francisco, CA",37743429,-122478198,True,"","",3250.0,"sqft",3049.0,"sqft",1939.0
# 15117892,"2178 22nd Ave, San Francisco, CA",37747074,-122478867,False,3.0,3.0,1518.0,"sqft",2996.0,"sqft",1928.0
# 15182629,"164-166 28TH St, San Francisco, CA",37745582,-122426143,False,"",3.0,1775.0,"sqft",2850.0,"sqft",1905.0
# 15068767,"767-771 Pine St, San Francisco, CA",37790971,-122408473,False,"",4.0,4605.0,"sqft",1376.0,"sqft",1909.0
# 15077572,"601 Van Ness Ave APT 48, San Francisco, CA",37781386,-122421406,False,2.0,2.0,1090.0,"sqft","","",1982.0
# 15094694,"539 5th Ave, San Francisco, CA",37778372,-122463348,False,"",1.0,925.0,"sqft",3000.0,"sqft",1907.0
# 15137743,"814 Detroit St, San Francisco, CA",37734098,-122444051,False,3.0,2.0,1510.0,"sqft",2613.0,"sqft",1941.0
# 83152921,"177 Townsend St UNIT 527, San Francisco, CA",37778980,-122391754,False,2.0,2.0,1019.0,"sqft","","",2007.0
# 15159831,"684 Precita Ave, San Francisco, CA",37747997,-122407987,False,4.0,3.0,2459.0,"sqft",2495.0,"sqft",1913.0
# 48188598,"2333 Jones St, San Francisco, CA",37802846,-122416772,False,"","",1494.0,"sqft","","",1927.0
# 15081160,"2820 Jackson St, San Francisco, CA",37791799,-122441680,False,5.0,3.5,3212.0,"sqft",3000.0,"sqft",1900.0
# 15200088,"2212 Castro St, San Francisco, CA",37743817,-122433688,False,4.0,4.0,4017.0,"sqft",2622.0,"sqft",2007.0
# 15145355,"429 Liberty St, San Francisco, CA",37756871,-122430875,False,2.0,2.0,1990.0,"sqft",3049.0,"sqft",1907.0
# 15194192,"169 Whipple Ave, San Francisco, CA",37711724,-122449278,False,3.0,1.0,1200.0,"sqft",2495.0,"sqft",1928.0
# 15188390,"1119 Cayuga Ave, San Francisco, CA",37720370,-122440519,False,"",1.0,1188.0,"sqft",2448.0,"sqft",1939.0
# 15078815,"545-547 Oak St, San Francisco, CA",37774030,-122428306,False,5.0,3.0,2610.0,"sqft",3297.0,"sqft",1900.0
# 15155000,"1 Jennings Ct, San Francisco, CA",37717794,-122397510,False,3.0,2.0,1310.0,"sqft","","",1995.0
# 15198984,"5 Red Rock Way # 75, San Francisco, CA",37745980,-122442612,False,3.0,2.0,1310.0,"sqft","","",1964.0
# 80751734,"300 Beale St APT 504, San Francisco, CA",37788139,-122392578,False,1.0,1.0,754.0,"sqft","","",1937.0
# 89238700,"1521 Sutter St APT 304, San Francisco, CA",37786731,-122425918,False,2.0,2.0,1098.0,"sqft","","",2008.0
# 15147213,"1059 Noe St, San Francisco, CA",37752026,-122431666,False,3.0,2.5,2545.0,"sqft",2269.0,"sqft",1912.0
# 15183908,"1759-1761 Dolores St, San Francisco, CA",37741487,-122423862,True,"","",1820.0,"sqft",1306.0,"sqft",1910.0
# 2101807538,"2619 Sacramento St, San Francisco, CA",37789371,-122436058,True,"","","","",2038.0,"sqft",1900.0
# 15151012,"961 San Bruno Ave, San Francisco, CA",37757433,-122404508,False,2.0,2.0,1297.0,"sqft",1920.0,"sqft",1927.0
# 15107765,"1587 43rd Ave, San Francisco, CA",37757107,-122502756,False,3.0,4.0,2165.0,"sqft",2374.0,"sqft",1936.0
# 15097633,"623 23rd Ave, San Francisco, CA",37775847,-122482595,False,2.0,1.0,1085.0,"sqft",2770.0,"sqft",1920.0
# 15095966,"699 36th Ave APT 408, San Francisco, CA",37775999,-122496550,False,3.0,3.0,1639.0,"sqft",1742.0,"sqft",1997.0
# 15114643,"1962 23rd Ave, San Francisco, CA",37751021,-122480217,False,"",1.0,1500.0,"sqft",2996.0,"sqft",1940.0
# 15102704,"1351 10th Ave, San Francisco, CA",37763010,-122467642,False,2.0,1.0,1152.0,"sqft",2996.0,"sqft",1940.0
# 54854510,"164A Parker Ave, San Francisco, CA",37782514,-122454028,False,2.0,1.0,1152.0,"sqft","","",1917.0
# 80738064,"761 Tehama St APT 1, San Francisco, CA",37775009,-122411787,False,2.0,2.0,1401.0,"sqft","","",2001.0
# 15139677,"107 Foerster St, San Francisco, CA",37729273,-122449109,False,4.0,2.0,1453.0,"sqft",2250.0,"sqft",1922.0
# 64972578,"333 1st St PH 2103, San Francisco, CA",37787029,-122393638,False,1.0,1.0,713.0,"sqft","","",2004.0
# 15156203,"1448 Oakdale Ave, San Francisco, CA",37733196,-122387320,False,3.0,2.0,2066.0,"sqft",2500.0,"sqft",1910.0
# ...
# 64971339,"3466 Scott St, San Francisco, CA",37802104,-122441277,False,2.0,1.0,1371.0,"sqft","","",1925.0
# 15183460,"68 30TH St, San Francisco, CA",37742601,-122422378,False,"",3.0,2800.0,"sqft",3049.0,"sqft",1908.0
# 15079279,"101-105 Steiner St, San Francisco, CA",37769994,-122431983,False,"",3.0,6726.0,"sqft",2735.0,"sqft",1900.0
# 15145020,"3928 20th St, San Francisco, CA",37758289,-122428794,False,4.0,4.0,3500.0,"sqft",2848.0,"sqft",1913.0
# 15087641,"805-807 Clayton St, San Francisco, CA",37766773,-122448261,False,"","",2950.0,"sqft",2495.0,"sqft",1910.0
# 59779295,"2341 Francisco St, San Francisco, CA",37800533,-122443740,False,2.0,2.0,1415.0,"sqft","","",1927.0
# 15066959,"1300 Pacific Ave, San Francisco, CA",37795805,-122416840,True,"",2.0,989.0,"sqft","","",1910.0
# 89240616,"301 Main St # T23C, San Francisco, CA",37789333,-122391698,False,1.0,1.0,809.0,"sqft","","",2008.0
# 15179953,"4475 24th St APT 2, San Francisco, CA",37750616,-122442268,False,2.0,1.0,837.0,"sqft","","",1976.0
# 15143976,"648-652 S Van Ness Ave, San Francisco, CA",37762704,-122417605,False,2.0,1.0,4275.0,"sqft",3062.0,"sqft",1911.0
# 15167071,"131 Brussels St, San Francisco, CA",37730359,-122406597,False,4.0,3.0,2269.0,"sqft",2761.0,"sqft",1916.0
# 15146149,"849 Sanchez St, San Francisco, CA",37755720,-122429819,False,3.0,3.5,2935.0,"sqft",2212.0,"sqft",1938.0
# 15104676,"1475 37th Ave, San Francisco, CA",37759458,-122496532,False,2.0,1.5,1713.0,"sqft",3049.0,"sqft",1937.0
# 15143887,"3065-3069 16TH St, San Francisco, CA",37764699,-122420993,False,"",4.0,5325.0,"sqft",2896.0,"sqft",1909.0
# 15179745,"305 Guttenberg St, San Francisco, CA",37709222,-122442361,False,4.0,2.5,1655.0,"sqft",1960.0,"sqft",1964.0
# 15190928,"284 Howth St, San Francisco, CA",37719944,-122451772,False,2.0,1.0,1280.0,"sqft",2247.0,"sqft",1930.0
# 15146704,"62-64 San Jose Ave, San Francisco, CA",37754174,-122421710,True,"","",2720.0,"sqft",1742.0,"sqft",1922.0
# 89239815,"472 12th Ave, San Francisco, CA",37779371,-122470275,False,2.0,1.0,1508.0,"sqft","","",1931.0
# 80747693,"1050 N Point St APT 1606, San Francisco, CA",37805426,-122424814,False,2.0,2.0,"","","","",1963.0
# 15130980,"4217 22nd St, San Francisco, CA",37754011,-122439170,False,2.0,2.0,1913.0,"sqft",1742.0,"sqft",1908.0
# 59700133,"557 Birch St, San Francisco, CA",37777827,-122425790,False,3.0,3.0,1635.0,"sqft",1500.0,"sqft",2001.0
# 15122750,"2466 18th Ave, San Francisco, CA",37741870,-122474209,False,2.0,1.0,1150.0,"sqft",2996.0,"sqft",1923.0
# 15189028,"111 Harold Ave, San Francisco, CA",37720294,-122453327,False,2.0,1.0,1087.0,"sqft",1742.0,"sqft",1947.0
# 15103602,"1394-1396 35TH Ave, San Francisco, CA",37761121,-122493960,False,"",2.0,1700.0,"sqft",1738.0,"sqft",1944.0
# 15078953,"789-793 Page St, San Francisco, CA",37772439,-122433608,False,6.0,3.0,3825.0,"sqft",2247.0,"sqft",1911.0
# 2100831587,"164 Parker Ave # B, San Francisco, CA",37782512,-122454025,False,2.0,1.0,"","","","",""
# 2099906047,"718 Long Bridge St #901, San Francisco, CA",37771506,-122394356,False,2.0,2.0,1200.0,"sqft","","",""
# 15096806,"744 44th Ave, San Francisco, CA",37774487,-122504423,False,4.0,3.0,2380.0,"sqft",4199.0,"sqft",1926.0
# 15184575,"2576 Diamond St, San Francisco, CA",37737683,-122434960,False,2.0,2.0,878.0,"sqft",2500.0,"sqft",1906.0
# 15133303,"584 Dewey Blvd, San Francisco, CA",37744232,-122463546,False,3.0,2.25,2282.0,"sqft",3833.0,"sqft",1923.0
# 15180812,"1257 Dolores St # A, San Francisco, CA",37749335,-122424491,False,1.0,1.0,950.0,"sqft","","",1910.0
# 89238425,"1326 Lyon St, San Francisco, CA",37783218,-122444229,False,2.0,1.5,1300.0,"sqft","","",1906.0
# 15144348,"4024-4026 18TH St, San Francisco, CA",37761209,-122433429,False,2.0,"",2148.0,"sqft",2500.0,"sqft",1900.0
# 63196937,"1265 Masonic Ave # C, San Francisco, CA",37769369,-122445536,False,2.0,2.0,1596.0,"sqft",3453.0,"sqft",1904.0
# 80730989,"2002 3rd St APT 212, San Francisco, CA",37763988,-122389167,False,2.0,2.0,1358.0,"sqft","","",2002.0
# 15111559,"1755 11th Ave, San Francisco, CA",37755442,-122468189,False,2.0,1.5,1250.0,"sqft",3000.0,"sqft",1924.0
# 15199947,"179 Topaz Way, San Francisco, CA",37740080,-122437123,False,4.0,4.5,3692.0,"sqft",2821.0,"sqft",1973.0
# 15091143,"262-264 17TH Ave, San Francisco, CA",37783126,-122476032,False,2.0,1.0,3410.0,"sqft",3000.0,"sqft",1916.0
# 89237721,"301 Main St # T28F, San Francisco, CA",37789333,-122391698,False,2.0,2.0,1323.0,"sqft","","",2008.0
# 15101068,"1223 41st Ave, San Francisco, CA",37763885,-122501124,False,3.0,2.0,1771.0,"sqft",2996.0,"sqft",1938.0
# 89240438,"6 Mint Plz APT 702A, San Francisco, CA",37783080,-122407541,False,3.0,3.0,1670.0,"sqft","","",1900.0
# 15087654,"814 Cole St, San Francisco, CA",37766481,-122449790,False,5.0,2.0,3000.0,"sqft",2687.0,"sqft",1906.0
# 2099976986,"639 35th Ave, San Francisco, CA",37776897,-122495582,False,9.0,6.0,2790.0,"sqft",3005.0,"sqft",1900.0
# 15070807,"1763-1765 Chestnut St, San Francisco, CA",37801061,-122432273,False,"",3.0,3260.0,"sqft",3000.0,"sqft",1920.0
# 71713698,"50 Lansing St UNIT 201, San Francisco, CA",37786148,-122394291,False,2.0,2.0,1202.0,"sqft","","",2006.0
# 15136211,"656 Teresita Blvd, San Francisco, CA",37736383,-122446101,False,3.0,2.0,1218.0,"sqft",2191.0,"sqft",1940.0
# 15105121,"2338 Kirkham St, San Francisco, CA",37759673,-122486164,False,2.0,2.5,1305.0,"sqft",2613.0,"sqft",1946.0
# 15077725,"601 Van Ness Ave APT 201, San Francisco, CA",37781386,-122421406,False,1.0,1.0,750.0,"sqft","","",1982.0
# 15195679,"1088 Huron Ave # 1, San Francisco, CA",37708438,-122454570,False,1.0,1.0,596.0,"sqft","","",1999.0
# 15181250,"4069 25th St, San Francisco, CA",37749628,-122430985,False,5.0,1.5,1837.0,"sqft",2848.0,"sqft",1905.0
# 15191017,"229 Tara St, San Francisco, CA",37719518,-122449364,False,3.0,1.0,2050.0,"sqft",2639.0,"sqft",1931.0
# 15147987,"130A Langton St # A, San Francisco, CA",37775760,-122407960,False,2.0,1.5,1000.0,"sqft","","",1906.0
# 117672217,"1840 Washington St APT 603, San Francisco, CA",37793212,-122423744,False,1.0,1.0,837.0,"sqft","","",2012.0
# 15078536,"640 Steiner St, San Francisco, CA",37775399,-122432491,False,2.0,2.0,1593.0,"sqft","","",1895.0
# 15077602,"601 Van Ness Ave APT 78, San Francisco, CA",37781386,-122421406,False,2.0,2.0,952.0,"sqft","","",1982.0
# 15152040,"2250 24th St APT 223, San Francisco, CA",37753905,-122402020,False,2.0,1.0,839.0,"sqft","","",1989.0
# 79841585,"38 Belcher St APT 2, San Francisco, CA",37768651,-122430499,False,2.0,1.0,862.0,"sqft","","",""
# 15084143,"270 Ewing Ter, San Francisco, CA",37779676,-122449096,False,2.0,1.0,1250.0,"sqft",2178.0,"sqft",1940.0
# 94976253,"330 Berry St UNIT 506, San Francisco, CA",37773529,-122396743,False,2.0,2.0,903.0,"sqft","","",2009.0
# 15130589,"264 Grand View Ave, San Francisco, CA",37754001,-122441489,False,1.0,1.0,590.0,"sqft",2613.0,"sqft",1907.0
# 15072504,"2660 Scott St, San Francisco, CA",37794473,-122439703,False,7.0,8.0,9190.0,"sqft",5623.0,"sqft",1908.0
# 15135298,"251 Kensington Way, San Francisco, CA",37742605,-122461714,False,3.0,1.25,2000.0,"sqft",3070.0,"sqft",1936.0
# 15123111,"2563 16th Ave, San Francisco, CA",37740144,-122472598,False,3.0,2.0,1625.0,"sqft",3049.0,"sqft",1927.0
# 115828655,"480 Mission Bay Blvd N UNIT 614, San Francisco, CA",37771155,-122389034,False,1.0,1.0,928.0,"sqft","","",2012.0
# 2099929240,"1323 Cortland Ave, San Francisco, CA",37740030,-122411000,"","","","","","","",""
# 15153857,"1243 Quesada Ave, San Francisco, CA",37728318,-122383131,False,2.0,1.0,1250.0,"sqft",2613.0,"sqft",1927.0
# 15070227,"134 Alhambra St, San Francisco, CA",37802318,-122438801,False,3.0,3.0,2599.0,"sqft",3005.0,"sqft",1925.0
# 15192245,"268 Thrift St, San Francisco, CA",37717704,-122461487,False,2.0,1.0,1000.0,"sqft",3049.0,"sqft",1953.0
# 15146876,"934 Shotwell St, San Francisco, CA",37752854,-122415524,False,"",1.0,1590.0,"sqft",4896.0,"sqft",1900.0
# 15137860,"430 Mangels Ave, San Francisco, CA",37733308,-122447346,False,2.0,1.0,1200.0,"sqft",2500.0,"sqft",1931.0
# 15126467,"130 Vale Ave, San Francisco, CA",37734905,-122483854,False,3.0,1.5,1272.0,"sqft",4199.0,"sqft",1939.0
# 69817812,"9 Lafayette St # 3, San Francisco, CA",37773411,-122417548,False,2.0,2.0,1215.0,"sqft","","",2003.0
# 15162353,"222 Anderson St, San Francisco, CA",37740024,-122415385,False,2.0,1.0,1280.0,"sqft",1742.0,"sqft",1906.0
# 15179059,"681 Morse St, San Francisco, CA",37710979,-122445586,False,3.0,1.0,1150.0,"sqft",2825.0,"sqft",1906.0
# 119685045,"2828 Polk St, San Francisco, CA",37802829,-122423092,False,2.0,2.0,1325.0,"sqft","","",1941.0
# 15071577,"1374 Union St, San Francisco, CA",37798870,-122421845,False,3.0,3.5,3105.0,"sqft","","",1907.0
# 124862135,"8 Octavia St, San Francisco, CA",37772548,-122423362,False,2.0,2.0,1001.0,"sqft","","",2014.0
# 125089501,"150 Grand View Ave, San Francisco, CA",37755622,-122440528,"","","","","",44.0,"sqft",1900.0
# 15086964,"1576 Waller St, San Francisco, CA",37768882,-122450080,False,3.0,1.0,1668.0,"sqft","","",1900.0
# 80737517,"303 Langton St # 2, San Francisco, CA",37773690,-122404988,False,2.0,1.5,1220.0,"sqft","","",1997.0
# 15067890,"1250 Jones St APT 503, San Francisco, CA",37793071,-122414049,False,1.0,1.0,1250.0,"sqft","","",1929.0
# 15101927,"1271 21st Ave, San Francisco, CA",37764011,-122479634,True,"","",3170.0,"sqft",3001.0,"sqft",1983.0
# 111931130,"860 Waller St APT 1, San Francisco, CA",37770488,-122437927,False,2.0,2.0,1105.0,"sqft","","",""
# 15156830,"250 Bayview Cir, San Francisco, CA",37734490,-122396289,False,2.0,2.0,1301.0,"sqft",1845.0,"sqft",1986.0
# 15166257,"52 Maynard St, San Francisco, CA",37729024,-122429396,False,4.0,3.0,2064.0,"sqft",2949.0,"sqft",1979.0
# 53153325,"10 Carmel St, San Francisco, CA",37761104,-122446788,False,4.0,5.5,1960.0,"sqft","","",1915.0
# 15093237,"586-588 42ND Ave, San Francisco, CA",37777620,-122502614,False,2.0,1.0,864.0,"sqft",1438.0,"sqft",1945.0
# 15118458,"2279 47th Ave, San Francisco, CA",37743999,-122506182,False,4.0,3.0,2570.0,"sqft",2996.0,"sqft",1900.0
# 61325365,"1325 Indiana St UNIT 108, San Francisco, CA",37753680,-122390420,False,1.0,2.0,1121.0,"sqft","","",2002.0
# 15177425,"749 Prague St, San Francisco, CA",37711050,-122432921,False,"",1.0,1250.0,"sqft",3127.0,"sqft",1925.0
# 15177658,"1012 Saddleback Dr, San Francisco, CA",37709595,-122426935,False,3.0,2.0,963.0,"sqft","","",1989.0
# 15196282,"33 Santa Cruz Ave # 3, San Francisco, CA",37709136,-122465327,False,3.0,3.0,1738.0,"sqft",2299.0,"sqft",1976.0
# 59718417,"1451 Sanchez St, San Francisco, CA",37745862,-122428786,False,3.0,3.0,1960.0,"sqft","","",2001.0
# 15124563,"2670 47th Ave, San Francisco, CA",37736702,-122505008,False,4.0,3.0,1546.0,"sqft",3049.0,"sqft",1944.0
# 15130317,"350 Eureka St, San Francisco, CA",37756462,-122438189,False,4.0,2.0,1720.0,"sqft",3250.0,"sqft",1910.0
# 15151054,"948 Hampshire St, San Francisco, CA",37756888,-122407955,True,"",1.0,1215.0,"sqft",2495.0,"sqft",1900.0
# 119685912,"977 Guerrero St, San Francisco, CA",37755558,-122422897,False,2.0,1.0,1440.0,"sqft","","",1900.0
# 15092620,"3945 Clement St, San Francisco, CA",37781101,-122501742,False,3.0,2.5,2209.0,"sqft",2500.0,"sqft",1930.0
# 15199573,"448 Gold Mine Dr, San Francisco, CA",37739244,-122437100,False,4.0,3.0,2200.0,"sqft",2935.0,"sqft",1968.0
# 80734665,"142 Russ St STE 5, San Francisco, CA",37778152,-122407806,False,2.0,2.0,2198.0,"sqft","","",1999.0
# 2100850402,"1915 Diamond St, San Francisco, CA",37742141,-122435111,False,4.0,3.0,2400.0,"sqft",4356.0,"sqft",1910.0
# 15100309,"801 42nd Ave, San Francisco, CA",37773449,-122502803,False,3.0,3.0,2730.0,"sqft",2250.0,"sqft",1923.0
# 15079314,"457-461 Waller St, San Francisco, CA",37770797,-122431159,True,"","",3750.0,"sqft",3000.0,"sqft",1900.0
# 89238065,"338 Spear St UNIT 5J, San Francisco, CA",37789533,-122390371,False,1.0,1.0,1021.0,"sqft","","",2009.0
# 15154660,"991 Hollister Ave, San Francisco, CA",37718354,-122390556,False,3.0,1.0,1062.0,"sqft",2500.0,"sqft",1917.0
# 15152257,"2107-2109 24TH St, San Francisco, CA",37753108,-122400748,False,"",2.0,1500.0,"sqft",2500.0,"sqft",1908.0
# 89237766,"451 Kansas St UNIT 448, San Francisco, CA",37764114,-122402984,False,2.0,2.5,1030.0,"sqft","","",2007.0
# 61288454,"77 Dow Pl APT 507, San Francisco, CA",37784195,-122396605,False,1.0,2.0,1075.0,"sqft","","",2002.0
# 69817329,"955 Excelsior Ave, San Francisco, CA",37722655,-122425573,False,4.0,4.0,2134.0,"sqft",2495.0,"sqft",2005.0
# 15082108,"3016 Sacramento St, San Francisco, CA",37788970,-122442995,False,2.0,1.5,1408.0,"sqft","","",1890.0
# 122245120,"55 Alvarado St, San Francisco, CA",37754366,-122422347,False,2.0,1.0,994.0,"sqft","","",1906.0
# 72554809,"209 Lakeshore Ct, Richmond, CA",37729995,-122497001,False,1.0,1.0,549.0,"sqft","","",1991.0
# 15076156,"1533 Sutter St, San Francisco, CA",37786658,-122426481,False,6.0,7.5,7375.0,"sqft",2748.0,"sqft",1890.0
# 89237493,"425 1st St UNIT 4905, San Francisco, CA",37786064,-122392173,False,1.0,1.0,710.0,"sqft","","",2008.0
# 15174828,"666 Athens St, San Francisco, CA",37717609,-122431819,False,"",1.0,1250.0,"sqft",2495.0,"sqft",1950.0
# 53153554,"301 Bryant St APT 504, San Francisco, CA",37784512,-122391427,False,"",2.0,1239.0,"sqft","","",1998.0
# 89237930,"333 Main St # IT8H, San Francisco, CA",37788944,-122391075,False,1.0,1.0,835.0,"sqft","","",2008.0
# 2101505254,"333 Beale St, San Francisco, CA",37788280,-122392100,False,1.0,1.0,950.0,"sqft","","",2015.0
# 15099387,"735 22nd Ave, San Francisco, CA",37773876,-122481388,False,4.0,2.0,1800.0,"sqft",2996.0,"sqft",1921.0
# 15078419,"301 Gough St APT 3, San Francisco, CA",37776184,-122423007,False,1.0,1.0,626.0,"sqft","","",1999.0
# 15179263,"48 Brunswick St, San Francisco, CA",37711962,-122439018,False,2.0,1.0,1120.0,"sqft",1800.0,"sqft",1917.0
# 15161979,"3660 Folsom St, San Francisco, CA",37740726,-122413458,False,3.0,3.0,650.0,"sqft",1750.0,"sqft",1902.0
# 60825591,"77 Dow Pl APT 500, San Francisco, CA",37784195,-122396605,False,1.0,1.5,1092.0,"sqft","","",2002.0
# 15134371,"331 Teresita Blvd, San Francisco, CA",37741738,-122449895,False,2.0,1.0,1645.0,"sqft",3750.0,"sqft",1931.0
# 15147628,"81 Lansing St APT 410, San Francisco, CA",37785651,-122394030,False,1.0,1.0,855.0,"sqft","","",1995.0
# 15188066,"44 Holloway Ave, San Francisco, CA",37722072,-122453855,False,2.0,1.0,878.0,"sqft",2500.0,"sqft",1901.0
# 15159610,"3455 Keith St, San Francisco, CA",37719522,-122397995,False,"",1.0,1125.0,"sqft",1925.0,"sqft",1924.0
# 15075714,"1880 Steiner St APT 101, San Francisco, CA",37786575,-122434720,False,2.0,3.0,1332.0,"sqft","","",1999.0
# 15188028,"229 Lee Ave, San Francisco, CA",37722358,-122454450,False,"",2.0,2298.0,"sqft",4316.0,"sqft",1905.0
# 80738317,"650 Delancey St APT 109, San Francisco, CA",37782577,-122389991,False,"",2.0,1554.0,"sqft","","",1996.0
# 67395015,"8400 Oceanview Ter APT 218, San Francisco, CA",37710480,-122467645,False,1.0,1.0,700.0,"sqft","","",2002.0
# 15127261,"38 Levant St, San Francisco, CA",37764521,-122442597,False,2.0,1.5,1090.0,"sqft",3123.0,"sqft",1938.0
# 63197318,"765 Market St APT 27B, San Francisco, CA",37786220,-122404310,False,1.0,1.1,1004.0,"sqft","","",2001.0
# 15064669,"1055 Lombard St # C, San Francisco, CA",37801873,-122418834,False,2.0,3.0,1182.0,"sqft","","",1986.0
# 15142024,"59 Manor Dr, San Francisco, CA",37727581,-122464761,False,3.0,1.5,1575.0,"sqft",3009.0,"sqft",1930.0
# 61288364,"439 19th Ave, San Francisco, CA",37779545,-122478580,False,3.0,2.0,1544.0,"sqft","","",2001.0
# 69819412,"250 King St UNIT 410, San Francisco, CA",37777645,-122393430,False,1.0,1.0,822.0,"sqft","","",2004.0
# 82786211,"310 Townsend St APT 311, San Francisco, CA",37777027,-122395736,False,1.0,1.0,853.0,"sqft","","",2006.0
# 15103435,"1343 31st Ave, San Francisco, CA",37762152,-122490254,False,3.0,2.0,1886.0,"sqft",3000.0,"sqft",1934.0
# 15195183,"3916 Alemany Blvd, San Francisco, CA",37711527,-122467755,False,3.0,2.0,1300.0,"sqft",2553.0,"sqft",1941.0
# 15180783,"430 Fair Oaks St, San Francisco, CA",37749725,-122424094,False,4.0,3.0,2678.0,"sqft","","",1911.0
# 54854296,"720 Stockton St APT 3, San Francisco, CA",37792578,-122407366,False,2.0,2.0,886.0,"sqft","","",2001.0

# %% [markdown]
# > ## `pd.read_csv()`: load datasets from files (or even over the Internet)

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow-properties.csv')) ###assign it to a data frame "df"

# %% [markdown]
# > ## `DataFrame`

# %% [markdown]
# Let's check `df`'s type:

# %%
type(df) ###what is the type of df? "... .DataFrame" = it' a data frame, yay
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `df` is a `DataFrame`.  (http://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %% [markdown]
# A `DataFrame` stores tabular data.  Let's have a look at its content:

# %%
df
# Out:
#              ID                                      Address  Latitude  \
# 0    2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429
# 1      89239580   690 Market St UNIT 1705, San Francisco, CA  37788246
# 2      15131782  401 Grand View Ave APT 3, San Francisco, CA  37752157
# 3      15179502            250 Concord St, San Francisco, CA  37710141
# 4      52266124        88 King St APT 317, San Francisco, CA  37780630
# ..          ...                                          ...       ...
# 995    82786211   310 Townsend St APT 311, San Francisco, CA  37777027
# 996    15103435             1343 31st Ave, San Francisco, CA  37762152
# 997    15195183         3916 Alemany Blvd, San Francisco, CA  37711527
# 998    15180783          430 Fair Oaks St, San Francisco, CA  37749725
# 999    54854296     720 Stockton St APT 3, San Francisco, CA  37792578
#
#      Longitude IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  \
# 0   -122401860     False     ...        557.0      sqft      NaN         NaN
# 1   -122403198     False     ...       1050.0      sqft      NaN         NaN
# 2   -122442356     False     ...        937.0      sqft      NaN         NaN
# 3   -122442063     False     ...       1574.0      sqft   1947.0        sqft
# 4   -122389635     False     ...       1205.0      sqft      NaN         NaN
# ..         ...       ...     ...          ...       ...      ...         ...
# 995 -122395736     False     ...        853.0      sqft      NaN         NaN
# 996 -122490254     False     ...       1886.0      sqft   3000.0        sqft
# 997 -122467755     False     ...       1300.0      sqft   2553.0        sqft
# 998 -122424094     False     ...       2678.0      sqft      NaN         NaN
# 999 -122407366     False     ...        886.0      sqft      NaN         NaN
#
#      BuiltInYear
# 0         2010.0
# 1         2007.0
# 2         1983.0
# 3         1959.0
# 4         2000.0
# ..           ...
# 995       2006.0
# 996       1934.0
# 997       1941.0
# 998       1911.0
# 999       2001.0
#
# [1000 rows x 12 columns]

# %% [markdown]
# > ## `.head()`: first 5 (default) rows

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.head.html)

# %%
df.head()    ####".head" is by default 5 rowws
# Out:
#            ID                                      Address  Latitude  \
# 0  2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429
# 1    89239580   690 Market St UNIT 1705, San Francisco, CA  37788246
# 2    15131782  401 Grand View Ave APT 3, San Francisco, CA  37752157
# 3    15179502            250 Concord St, San Francisco, CA  37710141
# 4    52266124        88 King St APT 317, San Francisco, CA  37780630
#
#    Longitude IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  \
# 0 -122401860     False     ...        557.0      sqft      NaN         NaN
# 1 -122403198     False     ...       1050.0      sqft      NaN         NaN
# 2 -122442356     False     ...        937.0      sqft      NaN         NaN
# 3 -122442063     False     ...       1574.0      sqft   1947.0        sqft
# 4 -122389635     False     ...       1205.0      sqft      NaN         NaN
#
#    BuiltInYear
# 0       2010.0
# 1       2007.0
# 2       1983.0
# 3       1959.0
# 4       2000.0
#
# [5 rows x 12 columns]

# %%
df.head(7)   ###want more than 5 rows? (5 is default) then put number in parentheses
# Out:
#            ID                                      Address  Latitude  \
# 0  2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429
# 1    89239580   690 Market St UNIT 1705, San Francisco, CA  37788246
# 2    15131782  401 Grand View Ave APT 3, San Francisco, CA  37752157
# 3    15179502            250 Concord St, San Francisco, CA  37710141
# 4    52266124        88 King St APT 317, San Francisco, CA  37780630
# 5  2100994004             409 Miguel St, San Francisco, CA  37736625
# 6    15067755      1250 Clay St APT 306, San Francisco, CA  37793575
#
#    Longitude IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  \
# 0 -122401860     False     ...        557.0      sqft      NaN         NaN
# 1 -122403198     False     ...       1050.0      sqft      NaN         NaN
# 2 -122442356     False     ...        937.0      sqft      NaN         NaN
# 3 -122442063     False     ...       1574.0      sqft   1947.0        sqft
# 4 -122389635     False     ...       1205.0      sqft      NaN         NaN
# 5 -122427008     False     ...        400.0      sqft      NaN         NaN
# 6 -122413670     False     ...        541.0      sqft      NaN         NaN
#
#    BuiltInYear
# 0       2010.0
# 1       2007.0
# 2       1983.0
# 3       1959.0
# 4       2000.0
# 5          NaN
# 6       1950.0
#
# [7 rows x 12 columns]

# %% [markdown]
# > ## `.tail()`: last 5 (default) rows

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.tail.html)

# %%
df.tail()
# Out:
#            ID                                     Address  Latitude  \
# 995  82786211  310 Townsend St APT 311, San Francisco, CA  37777027
# 996  15103435            1343 31st Ave, San Francisco, CA  37762152
# 997  15195183        3916 Alemany Blvd, San Francisco, CA  37711527
# 998  15180783         430 Fair Oaks St, San Francisco, CA  37749725
# 999  54854296    720 Stockton St APT 3, San Francisco, CA  37792578
#
#      Longitude IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  \
# 995 -122395736     False     ...        853.0      sqft      NaN         NaN
# 996 -122490254     False     ...       1886.0      sqft   3000.0        sqft
# 997 -122467755     False     ...       1300.0      sqft   2553.0        sqft
# 998 -122424094     False     ...       2678.0      sqft      NaN         NaN
# 999 -122407366     False     ...        886.0      sqft      NaN         NaN
#
#      BuiltInYear
# 995       2006.0
# 996       1934.0
# 997       1941.0
# 998       1911.0
# 999       2001.0
#
# [5 rows x 12 columns]

# %% [markdown]
# > ## `.shape`: shape (i.e., number of rows and columns)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.shape.html)

# %%
df.shape   ###how many rows, how many columns? will return a tuple. first element is number of
            ####rows, next is number of columns
             ####cannot write df.shape() bc it is a tuple, can't manipulate
# Out:
# (1000, 12)

# %% [markdown]
# The first value (at index 0) is the number of rows, the second (at index 1), the number of columns:

# %%
df.shape[0]   ###what is the first element?
# Out:
# 1000

# %%
df.shape[1]    ###what is the second element?
# Out:
# 12

# %% [markdown]
# You can also use the idiomatic Python `len` function to get the number of rows:

# %%
len(df)   ####how many rows do you have? 
             ##### cannot get number of columns with len(), have to use xx.shape
# Out:
# 1000

# %% [markdown]
# > ## `.dtypes`: column types

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dtypes.html)
# - (http://pandas.pydata.org/pandas-docs/stable/basics.html)

# %%
df.dtypes
# Out:
# ID               int64
# Address         object
# Latitude         int64
# Longitude        int64
# IsAStudio       object
#                 ...
# Size           float64
# SizeUnit        object
# LotSize        float64
# LotSizeUnit     object
# BuiltInYear    float64
# Length: 12, dtype: object

# %% [markdown]
# > ## `.isnull()` and `.notnull()`: NaN (Not-a-Number)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.isnull.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.notnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.notnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.notnull.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.sum.html)

# %% [markdown]
# As a data scientist, we will have to decide what to do when encountering missing values (a.k.a, not-a-numbers).  We might decide to drop the row containing it, drop the whole column, or impute it.  Today, let's focus on finding these NaNs.

# %%
df.isnull()  ####output of this is also a dataframe (tabular)
# Out:
#         ID  Address  Latitude  Longitude  IsAStudio     ...        Size  \
# 0    False    False     False      False      False     ...       False
# 1    False    False     False      False      False     ...       False
# 2    False    False     False      False      False     ...       False
# 3    False    False     False      False      False     ...       False
# 4    False    False     False      False      False     ...       False
# ..     ...      ...       ...        ...        ...     ...         ...
# 995  False    False     False      False      False     ...       False
# 996  False    False     False      False      False     ...       False
# 997  False    False     False      False      False     ...       False
# 998  False    False     False      False      False     ...       False
# 999  False    False     False      False      False     ...       False
#
#      SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0       False     True         True        False
# 1       False     True         True        False
# 2       False     True         True        False
# 3       False    False        False        False
# 4       False     True         True        False
# ..        ...      ...          ...          ...
# 995     False     True         True        False
# 996     False    False        False        False
# 997     False    False        False        False
# 998     False     True         True        False
# 999     False     True         True        False
#
# [1000 rows x 12 columns]

# %%
df.isnull().sum()   #####lot size and lot size unit (high values) tend to be values with 
                         ####missing data
# Out:
# ID               0
# Address          0
# Latitude         0
# Longitude        0
# IsAStudio       14
#               ...
# Size            33
# SizeUnit        33
# LotSize        444
# LotSizeUnit    444
# BuiltInYear     25
# Length: 12, dtype: int64

# %% [markdown]
# In return, we get a new `DataFrame` with Boolean values.  `True` if the value is `NaN`, `False` otherwise.

# %% [markdown]
# We can also get the count per column:

# %%
df.isnull().sum()
# Out:
# ID               0
# Address          0
# Latitude         0
# Longitude        0
# IsAStudio       14
#               ...
# Size            33
# SizeUnit        33
# LotSize        444
# LotSizeUnit    444
# BuiltInYear     25
# Length: 12, dtype: int64

# %% [markdown]
# Summing again will return the number of cells in the `DataFrame` with missing values.

# %%
df.isnull().sum().sum()   ####total number of CELLS with no data
                        #####"L" suffix in result is just to tell you that it's a long number
# Out:
# 1215L

# %%
type(df.isnull().sum().sum())
# Out:
# long

# %% [markdown]
# Equivalently, we can also use the `.isnull()` function:

# %%
pd.isnull(df)   ###different way of getting the same answer
                ##### pd is for pandas
# Out:
#         ID  Address  Latitude  Longitude  IsAStudio     ...        Size  \
# 0    False    False     False      False      False     ...       False
# 1    False    False     False      False      False     ...       False
# 2    False    False     False      False      False     ...       False
# 3    False    False     False      False      False     ...       False
# 4    False    False     False      False      False     ...       False
# ..     ...      ...       ...        ...        ...     ...         ...
# 995  False    False     False      False      False     ...       False
# 996  False    False     False      False      False     ...       False
# 997  False    False     False      False      False     ...       False
# 998  False    False     False      False      False     ...       False
# 999  False    False     False      False      False     ...       False
#
#      SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0       False     True         True        False
# 1       False     True         True        False
# 2       False     True         True        False
# 3       False    False        False        False
# 4       False     True         True        False
# ..        ...      ...          ...          ...
# 995     False     True         True        False
# 996     False    False        False        False
# 997     False    False        False        False
# 998     False     True         True        False
# 999     False     True         True        False
#
# [1000 rows x 12 columns]

# %%
pd.isnull(df).sum()
# Out:
# ID               0
# Address          0
# Latitude         0
# Longitude        0
# IsAStudio       14
#               ...
# Size            33
# SizeUnit        33
# LotSize        444
# LotSizeUnit    444
# BuiltInYear     25
# Length: 12, dtype: int64

# %%
pd.isnull(df).sum().sum()
# Out:
# 1215L

# %% [markdown]
# We also also use `.notnull()`, its complement method:

# %%
df.notnull()
# Out:
#        ID  Address  Latitude  Longitude  IsAStudio     ...       Size  \
# 0    True     True      True       True       True     ...       True
# 1    True     True      True       True       True     ...       True
# 2    True     True      True       True       True     ...       True
# 3    True     True      True       True       True     ...       True
# 4    True     True      True       True       True     ...       True
# ..    ...      ...       ...        ...        ...     ...        ...
# 995  True     True      True       True       True     ...       True
# 996  True     True      True       True       True     ...       True
# 997  True     True      True       True       True     ...       True
# 998  True     True      True       True       True     ...       True
# 999  True     True      True       True       True     ...       True
#
#      SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0        True    False        False         True
# 1        True    False        False         True
# 2        True    False        False         True
# 3        True     True         True         True
# 4        True    False        False         True
# ..        ...      ...          ...          ...
# 995      True    False        False         True
# 996      True     True         True         True
# 997      True     True         True         True
# 998      True    False        False         True
# 999      True    False        False         True
#
# [1000 rows x 12 columns]

# %%
pd.notnull(df)
# Out:
#        ID  Address  Latitude  Longitude  IsAStudio     ...       Size  \
# 0    True     True      True       True       True     ...       True
# 1    True     True      True       True       True     ...       True
# 2    True     True      True       True       True     ...       True
# 3    True     True      True       True       True     ...       True
# 4    True     True      True       True       True     ...       True
# ..    ...      ...       ...        ...        ...     ...        ...
# 995  True     True      True       True       True     ...       True
# 996  True     True      True       True       True     ...       True
# 997  True     True      True       True       True     ...       True
# 998  True     True      True       True       True     ...       True
# 999  True     True      True       True       True     ...       True
#
#      SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0        True    False        False         True
# 1        True    False        False         True
# 2        True    False        False         True
# 3        True     True         True         True
# 4        True    False        False         True
# ..        ...      ...          ...          ...
# 995      True    False        False         True
# 996      True     True         True         True
# 997      True     True         True         True
# 998      True    False        False         True
# 999      True    False        False         True
#
# [1000 rows x 12 columns]

# %% [markdown]
# > ### `.index` and `.columns`: row and column labels

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.html)

# %% [markdown]
# Use the `.index` property to get the label for rows.  For columns, use the `.columns` property.

# %%
df.index ###labels on the rows; up to (not including ) stop. aka 0 - 999
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# In this specific case, rows are just numbered from 0 to 1,000.  Note that, similarly to Python's standard `range` function, this range also excludes the last number.

# %%
df.columns   ###label on the columns
# Out:
# Index([u'ID', u'Address', u'Latitude', u'Longitude', u'IsAStudio', u'Beds',
#        u'Baths', u'Size', u'SizeUnit', u'LotSize', u'LotSizeUnit',
#        u'BuiltInYear'],
#       dtype='object')

# %%
df.columns[3]
# Out:
# 'Longitude'

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# > ## `[ [] ]` and `[]`: subsetting on columns

# %% [markdown]
# Selecting specific columns is performed by using the `[]` operator.
#
# If the values passed to `[]` are non-integers, the `DataFrame` will attempt to match them to those in the `columns` property.

# %% [markdown]
# > Let's subset the `DataFrame` on columns `Size` and `SizeUnit`:

# %%
df[ ['Size', 'SizeUnit']   ]  ###looking at just a specific part of the data frame
# Out:
#        Size SizeUnit
# 0     557.0     sqft
# 1    1050.0     sqft
# 2     937.0     sqft
# 3    1574.0     sqft
# 4    1205.0     sqft
# ..      ...      ...
# 995   853.0     sqft
# 996  1886.0     sqft
# 997  1300.0     sqft
# 998  2678.0     sqft
# 999   886.0     sqft
#
# [1000 rows x 2 columns]

# %% [markdown]
# > How about just on `Address`?

# %%
df['Address']
# Out:
# 0        829 Folsom St UNIT 906, San Francisco, CA
# 1       690 Market St UNIT 1705, San Francisco, CA
# 2      401 Grand View Ave APT 3, San Francisco, CA
# 3                250 Concord St, San Francisco, CA
# 4            88 King St APT 317, San Francisco, CA
#                           ...
# 995     310 Townsend St APT 311, San Francisco, CA
# 996               1343 31st Ave, San Francisco, CA
# 997           3916 Alemany Blvd, San Francisco, CA
# 998            430 Fair Oaks St, San Francisco, CA
# 999       720 Stockton St APT 3, San Francisco, CA
# Name: Address, Length: 1000, dtype: object

# %%
type(df['Address'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# > ## `Series`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %% [markdown]
# Not passing a list will result in a `Series`:

# %%
df['Address']
# Out:
# 0        829 Folsom St UNIT 906, San Francisco, CA
# 1       690 Market St UNIT 1705, San Francisco, CA
# 2      401 Grand View Ave APT 3, San Francisco, CA
# 3                250 Concord St, San Francisco, CA
# 4            88 King St APT 317, San Francisco, CA
#                           ...
# 995     310 Townsend St APT 311, San Francisco, CA
# 996               1343 31st Ave, San Francisco, CA
# 997           3916 Alemany Blvd, San Francisco, CA
# 998            430 Fair Oaks St, San Francisco, CA
# 999       720 Stockton St APT 3, San Francisco, CA
# Name: Address, Length: 1000, dtype: object

# %%
df.Address
# Out:
# 0        829 Folsom St UNIT 906, San Francisco, CA
# 1       690 Market St UNIT 1705, San Francisco, CA
# 2      401 Grand View Ave APT 3, San Francisco, CA
# 3                250 Concord St, San Francisco, CA
# 4            88 King St APT 317, San Francisco, CA
#                           ...
# 995     310 Townsend St APT 311, San Francisco, CA
# 996               1343 31st Ave, San Francisco, CA
# 997           3916 Alemany Blvd, San Francisco, CA
# 998            430 Fair Oaks St, San Francisco, CA
# 999       720 Stockton St APT 3, San Francisco, CA
# Name: Address, Length: 1000, dtype: object

# %% [markdown]
# > Let's check the result type:

# %%
# TODO

# %% [markdown]
# Columns can also be retrieved using "attribute" access as `DataFrame`s add a property for each column with the names of the properties as the names of the columns.  This won't work however for columns that have spaces or dots in their name.

# %% [markdown]
# > Let's check the value of `df`'s `.Address` property:

# %%
foo = df.Address

# %%
# TODO
foo.name
# Out:
# 'Address'

# %% [markdown]
# > Use the `.name` property (not `.columns`, that's for a `DataFrame`) to get the name of the variable stored inside it.

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.name.html)

# %%
# TODO

# %% [markdown]
# > ## `[]`: slicing on rows

# %% [markdown]
# > E.g., on the first five rows:

# %%
lst = ['foo', 'bar', 'bonjour', 'bonsoir']

# %%
lst[:2]
# Out:
# ['foo', 'bar']

# %%
lst[2:4]
# Out:
# ['bonjour', 'bonsoir']

# %%
df[:5]
# Out:
#            ID                                      Address  Latitude  \
# 0  2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429
# 1    89239580   690 Market St UNIT 1705, San Francisco, CA  37788246
# 2    15131782  401 Grand View Ave APT 3, San Francisco, CA  37752157
# 3    15179502            250 Concord St, San Francisco, CA  37710141
# 4    52266124        88 King St APT 317, San Francisco, CA  37780630
#
#    Longitude IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  \
# 0 -122401860     False     ...        557.0      sqft      NaN         NaN
# 1 -122403198     False     ...       1050.0      sqft      NaN         NaN
# 2 -122442356     False     ...        937.0      sqft      NaN         NaN
# 3 -122442063     False     ...       1574.0      sqft   1947.0        sqft
# 4 -122389635     False     ...       1205.0      sqft      NaN         NaN
#
#    BuiltInYear
# 0       2010.0
# 1       2007.0
# 2       1983.0
# 3       1959.0
# 4       2000.0
#
# [5 rows x 12 columns]

# %% [markdown]
# > ## `.loc[]` and `.iloc[]`: subsetting rows by index label and location

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.loc.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.iloc.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.set_index.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.reset_index.html)

# %% [markdown]
# Until now, the index of the `DataFrame` is a numerical starting from 0 but you can specify which column(s) should be in the index.

# %% [markdown]
# > E.g., `ID`:

# %%
df.iloc[[6,7,12]]
# Out:
#           ID                                  Address  Latitude  Longitude  \
# 6   15067755  1250 Clay St APT 306, San Francisco, CA  37793575 -122413670
# 7   15112556         1819 26th Ave, San Francisco, CA  37753480 -122484273
# 12  79844821   638 19th St UNIT 10, San Francisco, CA  37762084 -122389007
#
#    IsAStudio     ...         Size  SizeUnit  LotSize LotSizeUnit  BuiltInYear
# 6      False     ...        541.0      sqft      NaN         NaN       1950.0
# 7      False     ...       1175.0      sqft   2996.0        sqft       1939.0
# 12     False     ...       1467.0      sqft      NaN         NaN       2007.0
#
# [3 rows x 12 columns]

# %%
df = df.set_index('ID')

# %%
df.index
# Out:
# Int64Index([2121978635,   89239580,   15131782,   15179502,   52266124,
#             2100994004,   15067755,   15112556,   15133321,   61288341,
#             ...
#               63197318,   15064669,   15142024,   61288364,   69819412,
#               82786211,   15103435,   15195183,   15180783,   54854296],
#            dtype='int64', name=u'ID', length=1000)

# %%
df    ####still have 1000 rows, but initially had 12 columns, now only have 11
        ### columns specified as index no longer on display
# Out:
#                                                 Address  Latitude  Longitude  \
# ID
# 2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429 -122401860
# 89239580     690 Market St UNIT 1705, San Francisco, CA  37788246 -122403198
# 15131782    401 Grand View Ave APT 3, San Francisco, CA  37752157 -122442356
# 15179502              250 Concord St, San Francisco, CA  37710141 -122442063
# 52266124          88 King St APT 317, San Francisco, CA  37780630 -122389635
# ...                                                 ...       ...        ...
# 82786211     310 Townsend St APT 311, San Francisco, CA  37777027 -122395736
# 15103435               1343 31st Ave, San Francisco, CA  37762152 -122490254
# 15195183           3916 Alemany Blvd, San Francisco, CA  37711527 -122467755
# 15180783            430 Fair Oaks St, San Francisco, CA  37749725 -122424094
# 54854296       720 Stockton St APT 3, San Francisco, CA  37792578 -122407366
#
#            IsAStudio  Beds     ...        Size  SizeUnit LotSize  LotSizeUnit  \
# ID                             ...
# 2121978635     False   1.0     ...       557.0      sqft     NaN          NaN
# 89239580       False   2.0     ...      1050.0      sqft     NaN          NaN
# 15131782       False   2.0     ...       937.0      sqft     NaN          NaN
# 15179502       False   4.0     ...      1574.0      sqft  1947.0         sqft
# 52266124       False   2.0     ...      1205.0      sqft     NaN          NaN
# ...              ...   ...     ...         ...       ...     ...          ...
# 82786211       False   1.0     ...       853.0      sqft     NaN          NaN
# 15103435       False   3.0     ...      1886.0      sqft  3000.0         sqft
# 15195183       False   3.0     ...      1300.0      sqft  2553.0         sqft
# 15180783       False   4.0     ...      2678.0      sqft     NaN          NaN
# 54854296       False   2.0     ...       886.0      sqft     NaN          NaN
#
#            BuiltInYear
# ID
# 2121978635      2010.0
# 89239580        2007.0
# 15131782        1983.0
# 15179502        1959.0
# 52266124        2000.0
# ...                ...
# 82786211        2006.0
# 15103435        1934.0
# 15195183        1941.0
# 15180783        1911.0
# 54854296        2001.0
#
# [1000 rows x 11 columns]

# %% [markdown]
# > E.g., row with index 15063505:

# %%
df.loc[[15063505]]   ###looking at specific house with above index
# Out:
#                                       Address  Latitude  Longitude IsAStudio  \
# ID
# 15063505  740 Francisco St, San Francisco, CA  37804420 -122417389     False
#
#           Beds     ...        Size  SizeUnit LotSize  LotSizeUnit BuiltInYear
# ID                 ...
# 15063505   NaN     ...      1430.0      sqft  2435.0         sqft      1948.0
#
# [1 rows x 11 columns]

# %% [markdown]
# Its name is its value in the index.

# %% [markdown]
# > E.g., rows with indices 15063505 and 15064044:

# %%
df.loc[[15063505, 15064044]]
# Out:
#                                            Address  Latitude  Longitude  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15064044  199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
#
#          IsAStudio  Beds     ...        Size  SizeUnit LotSize  LotSizeUnit  \
# ID                           ...
# 15063505     False   NaN     ...      1430.0      sqft  2435.0         sqft
# 15064044     False   1.0     ...      1060.0      sqft     NaN          NaN
#
#          BuiltInYear
# ID
# 15063505      1948.0
# 15064044      1930.0
#
# [2 rows x 11 columns]

# %%
df.loc[15064044] ##single bracket, get a series instead
# Out:
# Address        199 Chestnut St APT 5, San Francisco, CA
# Latitude                                       37804392
# Longitude                                    -122406590
# IsAStudio                                         False
# Beds                                                  1
#                                  ...
# Size                                               1060
# SizeUnit                                           sqft
# LotSize                                             NaN
# LotSizeUnit                                         NaN
# BuiltInYear                                        1930
# Name: 15064044, Length: 11, dtype: object

# %%
df.loc[15064044].Address
# Out:
# '199 Chestnut St APT 5, San Francisco, CA'

# %%
####.iloc looks at particular posiitons
####.loc looks at the values

# %% [markdown]
# > E.g., rows #1 and #3:

# %%
df.iloc[[1,3]]
# Out:
#                                              Address  Latitude  Longitude  \
# ID
# 89239580  690 Market St UNIT 1705, San Francisco, CA  37788246 -122403198
# 15179502           250 Concord St, San Francisco, CA  37710141 -122442063
#
#          IsAStudio  Beds     ...        Size  SizeUnit LotSize  LotSizeUnit  \
# ID                           ...
# 89239580     False   2.0     ...      1050.0      sqft     NaN          NaN
# 15179502     False   4.0     ...      1574.0      sqft  1947.0         sqft
#
#          BuiltInYear
# ID
# 89239580      2007.0
# 15179502      1959.0
#
# [2 rows x 11 columns]

# %% [markdown]
# > ## Subsetting rows by Boolean selection (a.k.a., masking)

# %% [markdown]
# Rows can also be selected by using Boolean selection, using an array calculated from the result of applying a logical condition on the values in any of the columns.  This allows us to build more complicated selections than those based simply upon index labels or positions.

# %% [markdown]
# > E.g., what homes have been built before 1900?

# %%
df.columns
# Out:
# Index([u'Address', u'Latitude', u'Longitude', u'IsAStudio', u'Beds', u'Baths',
#        u'Size', u'SizeUnit', u'LotSize', u'LotSizeUnit', u'BuiltInYear'],
#       dtype='object')

# %%
df.BuiltInYear
# Out:
# ID
# 2121978635    2010.0
# 89239580      2007.0
# 15131782      1983.0
# 15179502      1959.0
# 52266124      2000.0
#                ...
# 82786211      2006.0
# 15103435      1934.0
# 15195183      1941.0
# 15180783      1911.0
# 54854296      2001.0
# Name: BuiltInYear, Length: 1000, dtype: float64

# %% [markdown]
# > Let's subset on that `Series`:

# %%
df.BuiltInYear <1900  ####now want to select all the ones marked true
# Out:
# ID
# 2121978635    False
# 89239580      False
# 15131782      False
# 15179502      False
# 52266124      False
#               ...
# 82786211      False
# 15103435      False
# 15195183      False
# 15180783      False
# 54854296      False
# Name: BuiltInYear, Length: 1000, dtype: bool

# %%
df[   df.BuiltInYear < 1900  ]
# Out:
#                                                Address  Latitude  Longitude  \
# ID
# 123597388       667 Shotwell St # A, San Francisco, CA  37757851 -122415629
# 63197592               3021 20th St, San Francisco, CA  37758878 -122411147
# 15145720         956 S Van Ness Ave, San Francisco, CA  37757832 -122417139
# 119684777              967 Hayes St, San Francisco, CA  37775645 -122432222
# 15181209    1001 Diamond St # 1001A, San Francisco, CA  37749461 -122435844
# ...                                                ...       ...        ...
# 15065140   1407 Montgomery St APT 2, San Francisco, CA  37802299 -122404941
# 15084954       1954 Golden Gate Ave, San Francisco, CA  37778420 -122443073
# 15078536             640 Steiner St, San Francisco, CA  37775399 -122432491
# 15082108         3016 Sacramento St, San Francisco, CA  37788970 -122442995
# 15076156             1533 Sutter St, San Francisco, CA  37786658 -122426481
#
#           IsAStudio  Beds     ...        Size  SizeUnit LotSize  LotSizeUnit  \
# ID                            ...
# 123597388     False   1.0     ...      1212.0      sqft     NaN          NaN
# 63197592      False   1.0     ...      1267.0      sqft     NaN          NaN
# 15145720      False   4.0     ...      3500.0      sqft  4165.0         sqft
# 119684777     False   4.0     ...      3006.0      sqft     NaN          NaN
# 15181209      False   3.0     ...      2032.0      sqft  1913.0         sqft
# ...             ...   ...     ...         ...       ...     ...          ...
# 15065140      False   1.0     ...      1000.0      sqft     NaN          NaN
# 15084954      False   2.0     ...      1515.0      sqft     NaN          NaN
# 15078536      False   2.0     ...      1593.0      sqft     NaN          NaN
# 15082108      False   2.0     ...      1408.0      sqft     NaN          NaN
# 15076156      False   6.0     ...      7375.0      sqft  2748.0         sqft
#
#           BuiltInYear
# ID
# 123597388      1890.0
# 63197592       1890.0
# 15145720       1872.0
# 119684777      1885.0
# 15181209       1892.0
# ...               ...
# 15065140       1870.0
# 15084954       1895.0
# 15078536       1895.0
# 15082108       1890.0
# 15076156       1890.0
#
# [15 rows x 11 columns]

# %%
# TODO

# %% [markdown]
# Multiple conditions can be put together.

# %% [markdown]
# > E.g., subset for `BuiltInYear` below 1900 and `Size` over 1500:

# %%
df.[  df.BuiltInyear < 1900 and df.Size >1500 ]   ##wont work
# Out:
#   File "<ipython-input-240-460d335e98c7>", line 1
#     df.[  df.BuiltInyear < 1900 and df.Size >1500 ]   ##wont work
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# It is possible to subset on columns simultaneously.

# %% [markdown]
# > E.g., subset (a `DataFrame`) on `Address` for `BuiltInYear` below 1900 and `Size` over 1500:

# %%
# TODO

# %% [markdown]
# > To get a `Series` instead of a `DataFrame`:

# %%
# TODO

# %% [markdown]
# ## Part B | Wrangling the SF Housing dataset (take 2) with `pandas`

# %%
properties_df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow-properties.csv'), index_col = 'ID')
transactions_df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow-transactions.csv'), index_col = 'ID')

# %% [markdown]
# (`pd.read_csv` can load the dataset and set the index column for the `DataFrame` at the same time)

# %%
properties_df.head()
# Out:
#                                                 Address  Latitude  Longitude  \
# ID
# 2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429 -122401860
# 89239580     690 Market St UNIT 1705, San Francisco, CA  37788246 -122403198
# 15131782    401 Grand View Ave APT 3, San Francisco, CA  37752157 -122442356
# 15179502              250 Concord St, San Francisco, CA  37710141 -122442063
# 52266124          88 King St APT 317, San Francisco, CA  37780630 -122389635
#
#            IsAStudio  Beds     ...        Size  SizeUnit LotSize  LotSizeUnit  \
# ID                             ...
# 2121978635     False   1.0     ...       557.0      sqft     NaN          NaN
# 89239580       False   2.0     ...      1050.0      sqft     NaN          NaN
# 15131782       False   2.0     ...       937.0      sqft     NaN          NaN
# 15179502       False   4.0     ...      1574.0      sqft  1947.0         sqft
# 52266124       False   2.0     ...      1205.0      sqft     NaN          NaN
#
#            BuiltInYear
# ID
# 2121978635      2010.0
# 89239580        2007.0
# 15131782        1983.0
# 15179502        1959.0
# 52266124        2000.0
#
# [5 rows x 11 columns]

# %%
transactions_df.head()
# Out:
#          DateOfSale  SalePrice SalePriceUnit
# ID
# 15165953     1/5/16  650000.00             $
# 80749447   11/10/15       1.15            $M
# 15155751   11/10/15  665000.00             $
# 15143887   12/31/15       2.10            $M
# 15117639   12/23/15       1.35            $M

# %% [markdown]
# > ### Merge both `DataFrames`

# %% [markdown]
# (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html)

# %%
df = properties_df.merge(transactions_df,  left_index = True, right_index = True)

# %%
df.columns
# Out:
# Index([u'Address', u'Latitude', u'Longitude', u'IsAStudio', u'Beds', u'Baths',
#        u'Size', u'SizeUnit', u'LotSize', u'LotSizeUnit', u'BuiltInYear',
#        u'DateOfSale', u'SalePrice', u'SalePriceUnit'],
#       dtype='object')

# %%
df
# Out:
#                                                 Address  Latitude  Longitude  \
# ID
# 2121978635    829 Folsom St UNIT 906, San Francisco, CA  37781429 -122401860
# 89239580     690 Market St UNIT 1705, San Francisco, CA  37788246 -122403198
# 15131782    401 Grand View Ave APT 3, San Francisco, CA  37752157 -122442356
# 15179502              250 Concord St, San Francisco, CA  37710141 -122442063
# 52266124          88 King St APT 317, San Francisco, CA  37780630 -122389635
# ...                                                 ...       ...        ...
# 82786211     310 Townsend St APT 311, San Francisco, CA  37777027 -122395736
# 15103435               1343 31st Ave, San Francisco, CA  37762152 -122490254
# 15195183           3916 Alemany Blvd, San Francisco, CA  37711527 -122467755
# 15180783            430 Fair Oaks St, San Francisco, CA  37749725 -122424094
# 54854296       720 Stockton St APT 3, San Francisco, CA  37792578 -122407366
#
#            IsAStudio  Beds      ...       LotSizeUnit  BuiltInYear DateOfSale  \
# ID                              ...
# 2121978635     False   1.0      ...               NaN       2010.0    12/6/15
# 89239580       False   2.0      ...               NaN       2007.0   11/23/15
# 15131782       False   2.0      ...               NaN       1983.0   11/18/15
# 15179502       False   4.0      ...              sqft       1959.0    12/4/15
# 52266124       False   2.0      ...               NaN       2000.0   12/15/15
# ...              ...   ...      ...               ...          ...        ...
# 82786211       False   1.0      ...               NaN       2006.0    12/8/15
# 15103435       False   3.0      ...              sqft       1934.0   12/18/15
# 15195183       False   3.0      ...              sqft       1941.0   12/30/15
# 15180783       False   4.0      ...               NaN       1911.0   12/10/15
# 54854296       False   2.0      ...               NaN       2001.0   11/25/15
#
#             SalePrice SalePriceUnit
# ID
# 2121978635  675000.00             $
# 89239580         1.05            $M
# 15131782         1.03            $M
# 15179502    815000.00             $
# 52266124         1.16            $M
# ...               ...           ...
# 82786211    900000.00             $
# 15103435         1.25            $M
# 15195183    400000.00             $
# 15180783         2.29            $M
# 54854296         1.25            $M
#
# [1000 rows x 14 columns]

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# > ### Sort rows by increasing ID

# %% [markdown]
# (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_index.html)

# %%
df.sort_index(inplace = True)

# %%
df
# Out:
#                                                Address  Latitude  Longitude  \
# ID
# 15063471     55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505           740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609           819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044      199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257    111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# ...                                                ...       ...        ...
# 2124214951       412 Green St APT A, San Francisco, CA  37800040 -122406100
# 2126960082     355 1st St UNIT 1905, San Francisco, CA  37787029 -122393638
# 2128308939        33 Santa Cruz Ave, San Francisco, CA  37709136 -122465332
# 2131957929           1821 Grant Ave, San Francisco, CA  37803760 -122408531
# 2136213970            1200 Gough St, San Francisco, CA  37784770 -122424100
#
#            IsAStudio  Beds      ...       LotSizeUnit  BuiltInYear DateOfSale  \
# ID                              ...
# 15063471       False   1.0      ...               NaN       1980.0    12/4/15
# 15063505       False   NaN      ...              sqft       1948.0   11/30/15
# 15063609       False   2.0      ...              sqft       1976.0   11/12/15
# 15064044       False   1.0      ...               NaN       1930.0   12/11/15
# 15064257       False   2.0      ...               NaN       1993.0    1/15/16
# ...              ...   ...      ...               ...          ...        ...
# 2124214951      True   NaN      ...               NaN       2012.0    1/15/16
# 2126960082     False   1.0      ...               NaN       2004.0   11/20/15
# 2128308939     False   3.0      ...              sqft       1976.0   12/10/15
# 2131957929     False   2.0      ...               NaN       1975.0   12/15/15
# 2136213970     False   1.0      ...               NaN       1966.0    1/10/16
#
#             SalePrice SalePriceUnit
# ID
# 15063471    710000.00             $
# 15063505         2.15            $M
# 15063609         5.60            $M
# 15064044         1.50            $M
# 15064257    970000.00             $
# ...               ...           ...
# 2124214951  390000.00             $
# 2126960082  860000.00             $
# 2128308939  830000.00             $
# 2131957929  835000.00             $
# 2136213970  825000.00             $
#
# [1000 rows x 14 columns]

# %% [markdown]
# > ### Remove the `Latitude` and `Longitude` columns

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html)

# %%
df.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)

# %%
df.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-253-908f34c3071d> in <module>()
# ----> 1 df.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
#    3576             indexer = indexer[~mask]
#    3577         return self.delete(indexer)
#
# ValueError: labels ['Latitude' 'Longitude'] not contained in axis

# %%
df

# %% [markdown]
# > ### `SalePrice`: scale all amount to `$M`

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html)

# %%
df.SalePriceUnit.unique()   ###all possible values in a column .unique()
# Out:
# array(['$', '$M'], dtype=object)

# %%
df_1 = df[df.SalePriceUnit == '$'] ###all houses for which sales price is in dollars
df_1 = df_1.drop('SalePriceUnit', axis = 1) ##dont care about this column, drop it

# Scaling sale price to $M
df_1.SalePrice /= 10 ** 6 

df_6 = df[df.SalePriceUnit == '$M']
df_6 = df_6.drop('SalePriceUnit', axis = 1)

# %%
# Concatenate of two DataFrames by rows
df = pd.concat([df_1, df_6])

# %%
# Resort the new DataFrame
df.sort_index(inplace = True)

# %% [markdown]
# df_1

# %%
df_1
# Out:
#                                                Address IsAStudio  Beds  Baths  \
# ID
# 15063471     55 Vandewater St APT 9, San Francisco, CA     False   1.0    NaN
# 15064257    111 Chestnut St APT 403, San Francisco, CA     False   2.0    2.0
# 15064295    111 Chestnut St APT 702, San Francisco, CA     False   2.0    2.0
# 15064391     1821 Grant Ave APT 101, San Francisco, CA     False   1.0    1.0
# 15065032    101 Lombard St APT 116E, San Francisco, CA     False   1.0    1.0
# ...                                                ...       ...   ...    ...
# 2124214951       412 Green St APT A, San Francisco, CA      True   NaN    1.0
# 2126960082     355 1st St UNIT 1905, San Francisco, CA     False   1.0    1.0
# 2128308939        33 Santa Cruz Ave, San Francisco, CA     False   3.0    3.0
# 2131957929           1821 Grant Ave, San Francisco, CA     False   2.0    2.0
# 2136213970            1200 Gough St, San Francisco, CA     False   1.0    1.0
#
#               Size    ...    LotSize  LotSizeUnit BuiltInYear  DateOfSale  \
# ID                    ...
# 15063471     550.0    ...        NaN          NaN      1980.0     12/4/15
# 15064257    1299.0    ...        NaN          NaN      1993.0     1/15/16
# 15064295    1033.0    ...        NaN          NaN      1993.0    12/17/15
# 15064391    1048.0    ...        NaN          NaN      1975.0    12/15/15
# 15065032    1000.0    ...        NaN          NaN      1983.0     12/7/15
# ...            ...    ...        ...          ...         ...         ...
# 2124214951   264.0    ...        NaN          NaN      2012.0     1/15/16
# 2126960082   691.0    ...        NaN          NaN      2004.0    11/20/15
# 2128308939  1738.0    ...     2299.0         sqft      1976.0    12/10/15
# 2131957929  1048.0    ...        NaN          NaN      1975.0    12/15/15
# 2136213970   900.0    ...        NaN          NaN      1966.0     1/10/16
#
#            SalePrice
# ID
# 15063471       0.710
# 15064257       0.970
# 15064295       0.940
# 15064391       0.835
# 15065032       0.800
# ...              ...
# 2124214951     0.390
# 2126960082     0.860
# 2128308939     0.830
# 2131957929     0.835
# 2136213970     0.825
#
# [425 rows x 11 columns]

# %% [markdown]
# > ### `IsAStudio`: convert from a Boolean to a binary variable (i.e., 0 or 1)

# %%
# TODO

# %%
df.IsAStudio   ###IsAStudio has trues and false
                ####what if we wanted to convert to 0 and 1?

# %%
df.IsAStudio *= 1

# %%
df.IsAStudio

# %% [markdown]
# > ### `Size`

# %%
df.SizeUnit.unique()

# %% [markdown]
# Size is either in square feet or missing.  Almost no work needed except to remove size unit.

# %%
df.drop('SizeUnit', axis = 1, inplace = True)

# %% [markdown]
# > ### `LotSize`: scale all values to square feet

# %%
df.LotSizeUnit.unique()

# %% [markdown]
# Lot sizes are either in square feet or in acres.  Let's convert them all to square feet.

# %% [markdown]
# > Group #1: the `na` values:

# %%
df_na = df[df.LotSizeUnit.isnull()]
df_na = df_na.drop('LotSizeUnit', axis = 1)

df_na.shape[0]

# %% [markdown]
# > Group #2: the `sqft` values:

# %%
# TODO (use df_sqft)

# %% [markdown]
# > Group #3: the `ac` values:

# %%
# TODO (use df_ac)

# %% [markdown]
# > Let's scale these `acre` values into `sqft`:

# %%
# (1 acre = 43,560 sqft)

# TODO

# %% [markdown]
# Let's now put everything back together...

# %%
df = pd.concat([df_na, df_sqft, df_ac]).sort_index()

# %%
df

# %% [markdown]
# > ## `.to_csv`: save the `DataFrame` into a `.csv` file

# %% [markdown]
# At the end of each phase (i.e., wrangling) of your data science project, it is a good idea to save your dataset into disk.  Then for the next step, create a new Jupyther notebook and load your updated dataset

# %%
df.to_csv(os.path.join('..', 'datasets', 'dataset-03-zillow.csv'), index_label = 'ID')

# %% [markdown]
# ## Part C | Advanced topics

# %% [markdown]
# ### `.groupby()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %% [markdown]
# > What is the mean price of houses by number of bathrooms?

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-45e77923f5ba> in <module>()
# ----> 1 df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow.csv'))
#
# NameError: name 'pd' is not defined

# %%
df[ ['Baths', 'SalePrice'] ].groupby('Baths').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-da7220a36400> in <module>()
# ----> 1 df[ ['Baths', 'SalePrice'] ].groupby('Baths').mean()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### `.map()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html)

# %% [markdown]
# When converting `SalePrice`, `Size`, and `LotSize` into `$M` and sqft, we could also have done the following:

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow-transactions.csv'))

# %%
df.SalePriceUnit.unique()

# %%
df.SalePriceUnit.map({'$': 1. / (10 ** 6), '$M': 1.})

# %%
df.SalePrice *= df.SalePriceUnit.map({'$': 1. / (10 ** 6), '$M': 1.})

# %%
df.SalePrice

# %%
df.drop('SalePriceUnit', axis = 1, inplace = True)

# %%
df

# %% [markdown]
# > ### Activity:  Using `.map()`, convert `Size` and `LotSize` to sqft.

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow-properties.csv'))

# %%
# TODO

# %% [markdown]
# ### `.to_datetime()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-03-zillow.csv'))

# %%
df.DateOfSale

# %% [markdown]
# So far, the dates stored in the `DataFrame` are just strings.  We cannot easily extract the day, month, year.  Thanksfully, `pandas` provides some facilities to do so.

# %%
pd.to_datetime(df.DateOfSale)

# %%
df.DateOfSale = pd.to_datetime(df.DateOfSale)

# %% [markdown]
# ### `.apply()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html)

# %%
df.DateOfSale.apply(lambda date_of_sale: date_of_sale.year)

# %%
df['YearOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.year)
df['MonthOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.month)
df['DayOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.day)
df['WeekDayOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.weekday_name)

df.drop('DateOfSale', axis = 1, inplace = True)

# %% [markdown]
# Now, we have the day, day of the week, month, and year of the sale as features in our dataset.

# %%
df
