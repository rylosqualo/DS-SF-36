# %%
####practicing with a dataset that Ivan gave us on slack

# %%
import os

import numpy as np

import pandas as pd

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
df_dir = '/Users/nikka.keivanfar/Desktop'

# %%
df_file = os.path.join(df_dir, "storms.csv.gz")

# %%
df_file
# Out:
# '/Users/nikka.keivanfar/Desktop/storms.csv.gz'

# %%
ls
# Out:
# 01/                          05/
# 02/                          06/
# 03/                          7 17 practice dataset.ipynb
# 04/

# %%
df=pd.read_csv('/Users/nikka.keivanfar/Desktop/DataScience/storms.csv.gz')
# Out:
# /anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape[0]
# Out:
# 902297

# %%
len(df)
# Out:
# 902297

# %%
df.shape[1] ###there are 37 columns
# Out:
# 37

# %%
for column in df.columns:
    print column
# Out:
# STATE__
# BGN_DATE
# BGN_TIME
# TIME_ZONE
# COUNTY
# COUNTYNAME
# STATE
# EVTYPE
# BGN_RANGE
# BGN_AZI
# BGN_LOCATI
# END_DATE
# END_TIME
# COUNTY_END
# COUNTYENDN
# END_RANGE
# END_AZI
# END_LOCATI
# LENGTH
# WIDTH
# F
# MAG
# FATALITIES
# INJURIES
# PROPDMG
# PROPDMGEXP
# CROPDMG
# CROPDMGEXP
# WFO
# STATEOFFIC
# ZONENAMES
# LATITUDE
# LONGITUDE
# LATITUDE_E
# LONGITUDE_
# REMARKS
# REFNUM

# %%
df.isnull()
# Out:
#         STATE__  BGN_DATE  BGN_TIME  TIME_ZONE  COUNTY   ...    LONGITUDE  \
# 0         False     False     False      False   False   ...        False
# 1         False     False     False      False   False   ...        False
# 2         False     False     False      False   False   ...        False
# 3         False     False     False      False   False   ...        False
# 4         False     False     False      False   False   ...        False
# ...         ...       ...       ...        ...     ...   ...          ...
# 902292    False     False     False      False   False   ...        False
# 902293    False     False     False      False   False   ...        False
# 902294    False     False     False      False   False   ...        False
# 902295    False     False     False      False   False   ...        False
# 902296    False     False     False      False   False   ...        False
#
#         LATITUDE_E  LONGITUDE_  REMARKS  REFNUM
# ...

# %%
df.isnull().sum().sum() ###lots of missing values in the dataset
# Out:
# 6645709L

# %%
df.info
# Out:
# <bound method DataFrame.info of         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df.groupby('TIME_ZONE')

# %%
df.head
# Out:
# <bound method DataFrame.head of         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df.groupby('STATE').FATALITIES.count()
# Out:
# STATE
# AK     4391
# AL    22739
# AM     1879
# AN     3250
# AR    27102
#       ...
# WA     3312
# WI    19781
# WV     9099
# WY     7332
# XX        2
# Name: FATALITIES, Length: 72, dtype: int64

# %%
df.groupby('STATE').FATALITIES.count()
# Out:
# STATE
# AK     4391
# AL    22739
# AM     1879
# AN     3250
# AR    27102
#       ...
# WA     3312
# WI    19781
# WV     9099
# WY     7332
# XX        2
# Name: FATALITIES, Length: 72, dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [STATE__, BGN_DATE, BGN_TIME, TIME_ZONE, COUNTY, COUNTYNAME, STATE, EVTYPE, BGN_RANGE, BGN_AZI, BGN_LOCATI, END_DATE, END_TIME, COUNTY_END, COUNTYENDN, END_RANGE, END_AZI, END_LOCATI, LENGTH, WIDTH, F, MAG, FATALITIES, INJURIES, PROPDMG, PROPDMGEXP, CROPDMG, CROPDMGEXP, WFO, STATEOFFIC, ZONENAMES, LATITUDE, LONGITUDE, LATITUDE_E, LONGITUDE_, REMARKS, REFNUM]
# Index: []
#
# [0 rows x 37 columns]

# %%
df.dropna(axis=1)
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        PROPDMG CROPDMG  LONGITUDE  LONGITUDE_    REFNUM
# ...

# %%
df1 = df[['STATE', 'FATALITIES', 'INJURIES', 'COUNTY']]

# %%
df1
# Out:
#        STATE  FATALITIES  INJURIES  COUNTY
# 0         AL         0.0      15.0    97.0
# 1         AL         0.0       0.0     3.0
# 2         AL         0.0       2.0    57.0
# 3         AL         0.0       2.0    89.0
# 4         AL         0.0       2.0    43.0
# ...      ...         ...       ...     ...
# 902292    WY         0.0       0.0     7.0
# 902293    MT         0.0       0.0     9.0
# 902294    AK         0.0       0.0   213.0
# 902295    AK         0.0       0.0   202.0
# 902296    AL         0.0       0.0     6.0
#
# [902297 rows x 4 columns]

# %%
county_fatal = df.groupby('COUNTY').FATALITIES.count()

# %%
county_fatal
# Out:
# COUNTY
# 0.0       6456
# 1.0      17810
# 2.0       3452
# 3.0      16220
# 4.0       2593
#          ...
# 867.0       32
# 868.0       33
# 869.0       12
# 870.0        2
# 873.0        3
# Name: FATALITIES, Length: 557, dtype: int64

# %%
county_fatal.max()
# Out:
# 17810

# %%
county_fatal.plot.hist()

# %%
dfev = df[['EVTYPE']]

# %%
dfev.dropna(axis=1)
# Out:
#             EVTYPE
# 0          TORNADO
# 1          TORNADO
# 2          TORNADO
# 3          TORNADO
# 4          TORNADO
# ...            ...
# 902292   HIGH WIND
# 902293   HIGH WIND
# 902294   HIGH WIND
# 902295    BLIZZARD
# 902296  HEAVY SNOW
#
# [902297 rows x 1 columns]

# %%
df_damage = df[(df.FATALITIES > 0) | (df.INJURIES > 0)]
df_damage.EVTYPE.unique().shape ####220 unique events
# Out:
# (220,)

# %%
df_damage
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df_damage.describe()
# Out:
#             STATE__        COUNTY     BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  21929.000000  21929.000000  21929.000000     21929.0         0.0
# mean      28.080213     87.339733      0.855642         0.0         NaN
# std       16.312386     93.553515      2.838700         0.0         NaN
# min        1.000000      0.000000      0.000000         0.0         NaN
# 25%       13.000000     25.000000      0.000000         0.0         NaN
# 50%       28.000000     67.000000      0.000000         0.0         NaN
# 75%       42.000000    115.000000      0.000000         0.0         NaN
# max       92.000000    840.000000     80.000000         0.0         NaN
#
#            ...            LATITUDE     LONGITUDE    LATITUDE_E    LONGITUDE_  \
# count      ...        21929.000000  21929.000000  21929.000000  21929.000000
# mean       ...         2125.484245   5196.644626   1315.943089   3205.507866
# std        ...         1835.039405   4452.451562   1781.037339   4315.920601
# ...

# %%
df_damage.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'ICE STORM/FLASH FLOOD',
#        'WINTER STORM', 'HURRICANE OPAL/HIGH WINDS', 'DENSE FOG',
#        'RIP CURRENT', 'THUNDERSTORM WINDS', 'LIGHTNING', 'HEAT',
#        'HEAVY RAIN', 'COLD', 'FLOODING', 'FLASH FLOOD', 'EXTREME COLD',
#        'HIGH WIND', 'MARINE MISHAP', 'HIGH WIND/SEAS', 'HIGH SEAS',
#        'HIGH WINDS', 'DUST STORM', 'SLEET', 'FLOOD',
#        'THUNDERSTORM WINDS/HAIL', 'EXCESSIVE HEAT', 'GUSTY WINDS',
#        'HIGH SURF', 'WILD FIRES', 'HIGH', 'WINTER STORM HIGH WINDS',
#        'WINTER STORMS', 'THUNDERSTORM WIND', 'FLOOD/FLASH FLOOD',
#        'HEAVY SNOW', 'FUNNEL CLOUD', 'STRONG WIND', 'DRY MIRCOBURST WINDS',
#        'DRY MICROBURST', 'THUNDERSTORM WINDSS', 'ICE STORM', 'HEAT WAVE',
#        'UNSEASONABLY WARM', 'STRONG WINDS', 'BLIZZARD',
#        'WATERSPOUT TORNADO', 'HURRICANE ERIN', 'WATERSPOUT/TORNADO',
#        'WIND', 'STORM SURGE', 'WATERSPOUT', 'HURRICANE OPAL',
# ...

# %%
df_damage.groupby('STATE').FATALITIES.count()
# Out:
# STATE
# AK     74
# AL    890
# AM     12
# AN     12
# AR    729
#      ...
# VT     53
# WA    194
# WI    503
# WV    174
# WY    141
# Name: FATALITIES, Length: 63, dtype: int64

# %%
official_event_types = [
   'Astronomical Low Tide', 'Avalanche',
   'Blizzard', 'Coastal Flood', 'Cold/Wind Chill', 'Debris Flow',
   'Dense Fog', 'Dense Smoke', 'Drought', 'Dust Devil', 'Dust Storm',
   'Excessive Heat', 'Extreme Cold/Wind Chill', 'Flash Flood', 'Flood',
   'Frost/Freeze', 'Funnel Cloud', 'Freezing Fog', 'Hail', 'Heat',
   'Heavy Rain', 'Heavy Snow', 'High Surf', 'High Wind',
   'Hurricane (Typhoon)', 'Ice Storm', 'Lake-Effect Snow',
   'Lakeshore Flood', 'Lightning', 'Marine Hail', 'Marine High Wind',
   'Marine Strong Wind', 'Marine Thunderstorm Wind', 'Rip Current',
   'Seiche', 'Sleet', 'Storm Surge/Tide', 'Strong Wind',
   'Thunderstorm Wind', 'Tornado', 'Tropical Depression',
   'Tropical Storm', 'Tsunami', 'Volcanic Ash', 'Waterspout', 'Wildfire',
   'Winter Storm', 'Winter Weather',

   'OTHER'
]

# %%
official_event_types
# Out:
# ['Astronomical Low Tide',
#  'Avalanche',
#  'Blizzard',
#  'Coastal Flood',
#  'Cold/Wind Chill',
#  'Debris Flow',
#  'Dense Fog',
#  'Dense Smoke',
#  'Drought',
#  'Dust Devil',
#  'Dust Storm',
#  'Excessive Heat',
#  'Extreme Cold/Wind Chill',
#  'Flash Flood',
#  'Flood',
#  'Frost/Freeze',
#  'Funnel Cloud',
#  'Freezing Fog',
#  'Hail',
#  'Heat',
#  'Heavy Rain',
#  'Heavy Snow',
#  'High Surf',
#  'High Wind',
#  'Hurricane (Typhoon)',
#  'Ice Storm',
#  'Lake-Effect Snow',
#  'Lakeshore Flood',
#  'Lightning',
#  'Marine Hail',
#  'Marine High Wind',
#  'Marine Strong Wind',
#  'Marine Thunderstorm Wind',
#  'Rip Current',
#  'Seiche',
#  'Sleet',
#  'Storm Surge/Tide',
#  'Strong Wind',
#  'Thunderstorm Wind',
#  'Tornado',
#  'Tropical Depression',
#  'Tropical Storm',
#  'Tsunami',
#  'Volcanic Ash',
#  'Waterspout',
#  'Wildfire',
#  'Winter Storm',
#  'Winter Weather',
#  'OTHER']

# %%
type(official_event_types)
# Out:
# list

# %%
official_event_types_lower = []
for event in official_event_types:
   event = event.lower()
   official_event_types_lower.append(event)

# %%
official_event_types_lower
# Out:
# ['astronomical low tide',
#  'avalanche',
#  'blizzard',
#  'coastal flood',
#  'cold/wind chill',
#  'debris flow',
#  'dense fog',
#  'dense smoke',
#  'drought',
#  'dust devil',
#  'dust storm',
#  'excessive heat',
#  'extreme cold/wind chill',
#  'flash flood',
#  'flood',
#  'frost/freeze',
#  'funnel cloud',
#  'freezing fog',
#  'hail',
#  'heat',
#  'heavy rain',
#  'heavy snow',
#  'high surf',
#  'high wind',
#  'hurricane (typhoon)',
#  'ice storm',
#  'lake-effect snow',
#  'lakeshore flood',
#  'lightning',
#  'marine hail',
#  'marine high wind',
#  'marine strong wind',
#  'marine thunderstorm wind',
#  'rip current',
#  'seiche',
#  'sleet',
#  'storm surge/tide',
#  'strong wind',
#  'thunderstorm wind',
#  'tornado',
#  'tropical depression',
#  'tropical storm',
#  'tsunami',
#  'volcanic ash',
#  'waterspout',
#  'wildfire',
#  'winter storm',
#  'winter weather',
#  'other']

# %%
df_damage.EVTYPE.apply(str.lower)
# Out:
# 0             tornado
# 2             tornado
# 3             tornado
# 4             tornado
# 5             tornado
#              ...
# 901932    rip current
# 902002      high wind
# 902127      high wind
# 902128      high wind
# 902182      avalanche
# Name: EVTYPE, Length: 21929, dtype: object

# %%
df_damage
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
def to_lower_case(list):
   lower_case = []
   for event in list:
       event = event.lower()
       lower_case.append(event)
   return lower_case

# %%
official = to_lower_case(official_event_types)
print official
# Out:
# ['astronomical low tide', 'avalanche', 'blizzard', 'coastal flood', 'cold/wind chill', 'debris flow', 'dense fog', 'dense smoke', 'drought', 'dust devil', 'dust storm', 'excessive heat', 'extreme cold/wind chill', 'flash flood', 'flood', 'frost/freeze', 'funnel cloud', 'freezing fog', 'hail', 'heat', 'heavy rain', 'heavy snow', 'high surf', 'high wind', 'hurricane (typhoon)', 'ice storm', 'lake-effect snow', 'lakeshore flood', 'lightning', 'marine hail', 'marine high wind', 'marine strong wind', 'marine thunderstorm wind', 'rip current', 'seiche', 'sleet', 'storm surge/tide', 'strong wind', 'thunderstorm wind', 'tornado', 'tropical depression', 'tropical storm', 'tsunami', 'volcanic ash', 'waterspout', 'wildfire', 'winter storm', 'winter weather', 'other']

# %%
dataset = to_lower_case(df.EVTYPE.unique())
dataset
# Out:
# ['tornado',
#  'tstm wind',
#  'hail',
#  'freezing rain',
#  'snow',
#  'ice storm/flash flood',
#  'snow/ice',
#  'winter storm',
#  'hurricane opal/high winds',
#  'thunderstorm winds',
#  'record cold',
#  'hurricane erin',
#  'hurricane opal',
#  'heavy rain',
#  'lightning',
#  'thunderstorm wind',
#  'dense fog',
#  'rip current',
#  'thunderstorm wins',
#  'flash flood',
#  'flash flooding',
#  'high winds',
#  'funnel cloud',
#  'tornado f0',
#  'thunderstorm winds lightning',
#  'thunderstorm winds/hail',
#  'heat',
#  'wind',
#  'lighting',
#  'heavy rains',
#  'lightning and heavy rain',
#  'funnel',
#  'wall cloud',
#  'flooding',
#  'thunderstorm winds hail',
#  'flood',
#  'cold',
#  'heavy rain/lightning',
#  'flash flooding/thunderstorm wi',
#  'wall cloud/funnel cloud',
#  'thunderstorm',
#  'waterspout',
#  'extreme cold',
#  'hail 1.75)',
#  'lightning/heavy rain',
#  'high wind',
#  'blizzard',
#  'blizzard weather',
#  'wind chill',
#  'breakup flooding',
# ...

# %%
df2 = df[['STATE', 'FATALITIES', 'INJURIES', 'EVTYPE','LATITUDE','LONGITUDE']]

# %%
df2
# Out:
#        STATE  FATALITIES  INJURIES      EVTYPE  LATITUDE  LONGITUDE
# 0         AL         0.0      15.0     TORNADO    3040.0     8812.0
# 1         AL         0.0       0.0     TORNADO    3042.0     8755.0
# 2         AL         0.0       2.0     TORNADO    3340.0     8742.0
# 3         AL         0.0       2.0     TORNADO    3458.0     8626.0
# 4         AL         0.0       2.0     TORNADO    3412.0     8642.0
# ...      ...         ...       ...         ...       ...        ...
# 902292    WY         0.0       0.0   HIGH WIND       0.0        0.0
# 902293    MT         0.0       0.0   HIGH WIND       0.0        0.0
# 902294    AK         0.0       0.0   HIGH WIND       0.0        0.0
# 902295    AK         0.0       0.0    BLIZZARD       0.0        0.0
# 902296    AL         0.0       0.0  HEAVY SNOW       0.0        0.0
#
# [902297 rows x 6 columns]

# %%
df2.EVTYPE = df2.EVTYPE.apply(str.lower)
# Out:
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df2
# Out:
#        STATE  FATALITIES  INJURIES      EVTYPE  LATITUDE  LONGITUDE
# 0         AL         0.0      15.0     tornado    3040.0     8812.0
# 1         AL         0.0       0.0     tornado    3042.0     8755.0
# 2         AL         0.0       2.0     tornado    3340.0     8742.0
# 3         AL         0.0       2.0     tornado    3458.0     8626.0
# 4         AL         0.0       2.0     tornado    3412.0     8642.0
# ...      ...         ...       ...         ...       ...        ...
# 902292    WY         0.0       0.0   high wind       0.0        0.0
# 902293    MT         0.0       0.0   high wind       0.0        0.0
# 902294    AK         0.0       0.0   high wind       0.0        0.0
# 902295    AK         0.0       0.0    blizzard       0.0        0.0
# 902296    AL         0.0       0.0  heavy snow       0.0        0.0
#
# [902297 rows x 6 columns]

# %%
df2
# Out:
#        STATE  FATALITIES  INJURIES      EVTYPE  LATITUDE  LONGITUDE
# 0         AL         0.0      15.0     tornado    3040.0     8812.0
# 1         AL         0.0       0.0     tornado    3042.0     8755.0
# 2         AL         0.0       2.0     tornado    3340.0     8742.0
# 3         AL         0.0       2.0     tornado    3458.0     8626.0
# 4         AL         0.0       2.0     tornado    3412.0     8642.0
# ...      ...         ...       ...         ...       ...        ...
# 902292    WY         0.0       0.0   high wind       0.0        0.0
# 902293    MT         0.0       0.0   high wind       0.0        0.0
# 902294    AK         0.0       0.0   high wind       0.0        0.0
# 902295    AK         0.0       0.0    blizzard       0.0        0.0
# 902296    AL         0.0       0.0  heavy snow       0.0        0.0
#
# [902297 rows x 6 columns]

# %%
df2[df2.EVTYPE.isin(official_event_types_lower)]
# Out:
#        STATE  FATALITIES  INJURIES      EVTYPE  LATITUDE  LONGITUDE
# 0         AL         0.0      15.0     tornado    3040.0     8812.0
# 1         AL         0.0       0.0     tornado    3042.0     8755.0
# 2         AL         0.0       2.0     tornado    3340.0     8742.0
# 3         AL         0.0       2.0     tornado    3458.0     8626.0
# 4         AL         0.0       2.0     tornado    3412.0     8642.0
# ...      ...         ...       ...         ...       ...        ...
# 902292    WY         0.0       0.0   high wind       0.0        0.0
# 902293    MT         0.0       0.0   high wind       0.0        0.0
# 902294    AK         0.0       0.0   high wind       0.0        0.0
# 902295    AK         0.0       0.0    blizzard       0.0        0.0
# 902296    AL         0.0       0.0  heavy snow       0.0        0.0
#
# [635403 rows x 6 columns]

# %%
df_damage[df_damage.EVTYPE.isin(official_event_types_lower)]
# Out:
# Empty DataFrame
# Columns: [STATE__, BGN_DATE, BGN_TIME, TIME_ZONE, COUNTY, COUNTYNAME, STATE, EVTYPE, BGN_RANGE, BGN_AZI, BGN_LOCATI, END_DATE, END_TIME, COUNTY_END, COUNTYENDN, END_RANGE, END_AZI, END_LOCATI, LENGTH, WIDTH, F, MAG, FATALITIES, INJURIES, PROPDMG, PROPDMGEXP, CROPDMG, CROPDMGEXP, WFO, STATEOFFIC, ZONENAMES, LATITUDE, LONGITUDE, LATITUDE_E, LONGITUDE_, REMARKS, REFNUM]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_damage[df_damage.EVTYPE.isin(official_event_types_lower)]
# Out:
# Empty DataFrame
# Columns: [STATE__, BGN_DATE, BGN_TIME, TIME_ZONE, COUNTY, COUNTYNAME, STATE, EVTYPE, BGN_RANGE, BGN_AZI, BGN_LOCATI, END_DATE, END_TIME, COUNTY_END, COUNTYENDN, END_RANGE, END_AZI, END_LOCATI, LENGTH, WIDTH, F, MAG, FATALITIES, INJURIES, PROPDMG, PROPDMGEXP, CROPDMG, CROPDMGEXP, WFO, STATEOFFIC, ZONENAMES, LATITUDE, LONGITUDE, LATITUDE_E, LONGITUDE_, REMARKS, REFNUM]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_damage
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df2.STATE.unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI',
#        'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC',
#        'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT',
#        'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR', 'AK', 'ST', 'AS', 'GU',
#        'MH', 'VI', 'AM', 'LC', 'PH', 'GM', 'PZ', 'AN', 'LH', 'LM', 'LE',
#        'LS', 'SL', 'LO', 'PM', 'PK', 'XX'], dtype=object)

# %%
state_list = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','GU','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','PR','RI','SC','SD','TN','TX','UT','VT','VA','VI','WA','WV','WI','WY']

# %%
df_damage.STATE.isin(state_list).sum()/df_damage.shape[0]
# Out:
# 0

# %%
cols = list(df2.columns.values)

# %%
cols
# Out:
# ['STATE', 'FATALITIES', 'INJURIES', 'EVTYPE', 'LATITUDE', 'LONGITUDE']

# %%
df2 = df2[['STATE','EVTYPE','FATALITIES','INJURIES','LATITUDE','LONGITUDE']]

# %%
df2
# Out:
#        STATE      EVTYPE  FATALITIES  INJURIES  LATITUDE  LONGITUDE
# 0         AL     tornado         0.0      15.0    3040.0     8812.0
# 1         AL     tornado         0.0       0.0    3042.0     8755.0
# 2         AL     tornado         0.0       2.0    3340.0     8742.0
# 3         AL     tornado         0.0       2.0    3458.0     8626.0
# 4         AL     tornado         0.0       2.0    3412.0     8642.0
# ...      ...         ...         ...       ...       ...        ...
# 902292    WY   high wind         0.0       0.0       0.0        0.0
# 902293    MT   high wind         0.0       0.0       0.0        0.0
# 902294    AK   high wind         0.0       0.0       0.0        0.0
# 902295    AK    blizzard         0.0       0.0       0.0        0.0
# 902296    AL  heavy snow         0.0       0.0       0.0        0.0
#
# [902297 rows x 6 columns]

# %%
df2.groupby(['STATE','EVTYPE'])['FATALITIES', 'INJURIES'].mean()
# Out:
#                                 FATALITIES  INJURIES
# STATE EVTYPE
# AK    astronomical low tide       0.000000  0.000000
#       avalanche                   0.622642  0.320755
#       blizzard                    0.007856  0.005612
#       blizzard weather            0.000000  0.000000
#       blizzard/high wind          0.000000  0.000000
# ...                                    ...       ...
# WY    wild/forest fire            0.027027  0.027027
#       wildfire                    0.000000  0.263158
#       winter storm                0.011605  0.230174
#       winter weather              0.000000  0.000000
# XX    marine thunderstorm wind    0.000000  0.000000
#
# [4104 rows x 2 columns]

# %%
df2[ ['STATE','EVTYPE','FATALITIES', 'INJURIES'] ].groupby(['STATE']).mean()
# Out:
#        FATALITIES  INJURIES
# STATE
# AK       0.016853  0.025507
# AL       0.034478  0.384450
# AM       0.005322  0.015966
# AN       0.003692  0.007077
# AR       0.019556  0.204782
# ...           ...       ...
# WA       0.044082  0.227355
# WI       0.014104  0.116728
# WV       0.010111  0.039894
# WY       0.007638  0.058920
# XX       0.000000  0.000000
#
# [72 rows x 2 columns]

# %%
df2 = df[(df.FATALITIES > 0) | (df.INJURIES > 0)]
df2.EVTYPE.unique().shape ####220 unique events
# Out:
# (220,)

# %%
df2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df2.EVTYPE.apply(str.lower)
# Out:
# 0             tornado
# 2             tornado
# 3             tornado
# 4             tornado
# 5             tornado
#              ...
# 901932    rip current
# 902002      high wind
# 902127      high wind
# 902128      high wind
# 902182      avalanche
# Name: EVTYPE, Length: 21929, dtype: object

# %%
df2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df2.EVTYPE
# Out:
# 0             TORNADO
# 2             TORNADO
# 3             TORNADO
# 4             TORNADO
# 5             TORNADO
#              ...
# 901932    RIP CURRENT
# 902002      HIGH WIND
# 902127      HIGH WIND
# 902128      HIGH WIND
# 902182      AVALANCHE
# Name: EVTYPE, Length: 21929, dtype: object

# %%
df2[ ['STATE','EVTYPE','FATALITIES', 'INJURIES'] ].groupby(['STATE']).mean()
# Out:
#        FATALITIES  INJURIES
# STATE
# AK       1.000000  1.513514
# AL       0.880899  9.822472
# AM       0.833333  2.500000
# AN       1.000000  1.916667
# AR       0.727023  7.613169
# ...           ...       ...
# VT       0.433962  1.339623
# WA       0.752577  3.881443
# WI       0.554672  4.590457
# WV       0.528736  2.086207
# WY       0.397163  3.063830
#
# [63 rows x 2 columns]

# %%
df2[df2.EVTYPE.isin(official_event_types)]
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 251293      6.0   9/15/1996 0:00:00  10:30:00 AM       PST    73.0    ...
# 254085     15.0   3/16/1996 0:00:00  12:00:00 AM       HST     4.0    ...
# 254098     15.0   5/26/1996 0:00:00  10:00:00 AM       HST     2.0    ...
# 254117     15.0   7/22/1996 0:00:00  01:00:00 PM       HST     1.0    ...
# 254123     15.0  10/26/1996 0:00:00  11:00:00 PM       HST     1.0    ...
# 435358     35.0   7/15/2001 0:00:00  05:10:00 PM       MST    15.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# 251293       0.0        0.0        0.0
# 254085       0.0        0.0        0.0
# 254098       0.0        0.0        0.0
# 254117       0.0        0.0        0.0
# 254123       0.0        0.0        0.0
# 435358       0.0        0.0        0.0
#
#                                                   REMARKS    REFNUM
# 251293  Merchandise and pieces of tarpaulin were sent ...  251265.0
# ...

# %%
df2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 901932     12.0  11/10/2011 0:00:00  03:00:00 PM       EST    25.0    ...
# 902002     53.0  11/22/2011 0:00:00  03:43:00 AM       PST   517.0    ...
# 902127      8.0  11/12/2011 0:00:00  10:10:00 AM       MST    36.0    ...
# 902128      8.0  11/12/2011 0:00:00  12:51:00 PM       MST    38.0    ...
# 902182     49.0  11/13/2011 0:00:00  02:30:00 PM       MST     8.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df2.groupby(['STATE','EVTYPE'])['FATALITIES', 'INJURIES'].mean()
# Out:
#                         FATALITIES   INJURIES
# STATE EVTYPE
# AK    AVALANCHE           1.137931   0.586207
#       BLIZZARD            0.875000   0.625000
#       COASTAL FLOOD       1.500000   0.000000
#       EXCESSIVE HEAT      1.000000   0.000000
#       EXTREME COLD        1.000000   0.500000
# ...                            ...        ...
# WY    TORNADO             0.137931   3.482759
#       TSTM WIND           0.000000   2.750000
#       WILD/FOREST FIRE    1.000000   1.000000
#       WILDFIRE            0.000000   5.000000
#       WINTER STORM        0.600000  11.900000
#
# [1480 rows x 2 columns]

# %%
df2.groupby(['STATE','EVTYPE'])['FATALITIES', 'INJURIES'].sum()
####looking state by for each evtype, number of fatalities and injuries
# Out:
#                         FATALITIES  INJURIES
# STATE EVTYPE
# AK    AVALANCHE               33.0      17.0
#       BLIZZARD                 7.0       5.0
#       COASTAL FLOOD            3.0       0.0
#       EXCESSIVE HEAT           1.0       0.0
#       EXTREME COLD             2.0       1.0
# ...                            ...       ...
# WY    TORNADO                  4.0     101.0
#       TSTM WIND                0.0      11.0
#       WILD/FOREST FIRE         1.0       1.0
#       WILDFIRE                 0.0      10.0
#       WINTER STORM             6.0     119.0
#
# [1480 rows x 2 columns]

# %%
dfmost = df2.groupby(['STATE','EVTYPE'])['FATALITIES', 'INJURIES'].sum()

# %%
dfmost.max()
# Out:
# FATALITIES     653.0
# INJURIES      8207.0
# dtype: float64

# %%
dfmost.FATALITIES.value_counts()
# Out:
# 0.0      394
# 1.0      341
# 2.0      161
# 3.0       96
# 4.0       74
#         ...
# 57.0       1
# 42.0       1
# 110.0      1
# 44.0       1
# 359.0      1
# Name: FATALITIES, Length: 89, dtype: int64

# %%
dfmost[dfmost.FATALITIES == dfmost.FATALITIES.max()]
# Out:
#               FATALITIES  INJURIES
# STATE EVTYPE
# IL    HEAT         653.0     241.0

# %%
###max number of fatalities happened in illinois due to heat

# %%
df4 = df[['STATE','COUNTY','BGN_DATE', 'FATALITIES', 'INJURIES', 'EVTYPE','LATITUDE','LONGITUDE']]

# %%
df4
# Out:
#        STATE  COUNTY            BGN_DATE  FATALITIES  INJURIES      EVTYPE  \
# 0         AL    97.0   4/18/1950 0:00:00         0.0      15.0     TORNADO
# 1         AL     3.0   4/18/1950 0:00:00         0.0       0.0     TORNADO
# 2         AL    57.0   2/20/1951 0:00:00         0.0       2.0     TORNADO
# 3         AL    89.0    6/8/1951 0:00:00         0.0       2.0     TORNADO
# 4         AL    43.0  11/15/1951 0:00:00         0.0       2.0     TORNADO
# ...      ...     ...                 ...         ...       ...         ...
# 902292    WY     7.0  11/30/2011 0:00:00         0.0       0.0   HIGH WIND
# 902293    MT     9.0  11/10/2011 0:00:00         0.0       0.0   HIGH WIND
# 902294    AK   213.0   11/8/2011 0:00:00         0.0       0.0   HIGH WIND
# 902295    AK   202.0   11/9/2011 0:00:00         0.0       0.0    BLIZZARD
# 902296    AL     6.0  11/28/2011 0:00:00         0.0       0.0  HEAVY SNOW
#
#         LATITUDE  LONGITUDE
# 0         3040.0     8812.0
# ...

# %%
df4 = df4[(df.FATALITIES > 0) | (df.INJURIES > 0)]
df4.EVTYPE.unique().shape
# Out:
# (220,)

# %%
df4.groupby(['STATE','COUNTY','EVTYPE'])['FATALITIES', 'INJURIES'].sum()
####looking state by county for each evtype, number of fatalities and injuries
# Out:
#                                FATALITIES  INJURIES
# STATE COUNTY EVTYPE
# AK    0.0    HIGH WIND                0.0       1.0
#              MARINE MISHAP            7.0       5.0
#       1.0    BLIZZARD                 1.0       0.0
#              HEAVY SNOW               0.0       2.0
#       5.0    WILD/FOREST FIRE         0.0       9.0
# ...                                   ...       ...
# WY    67.0   HIGH WIND                0.0       4.0
#       69.0   HIGH WIND                0.0       2.0
#              ICY ROADS                1.0       2.0
#       70.0   BLIZZARD                 1.0       0.0
#       106.0  HIGH WIND                1.0       0.0
#
# [10016 rows x 2 columns]

# %%
df4county = df4county.groupby(['STATE','COUNTY','BGN_DATE','EVTYPE'])['FATALITIES', 'INJURIES'].sum()
####looking state by county for each evtype, number of fatalities and injuries

# %%
df4county
# Out:
#                                                FATALITIES  INJURIES
# STATE COUNTY BGN_DATE           EVTYPE
# AK    0.0    1/15/1995 0:00:00  MARINE MISHAP         6.0       0.0
#              1/27/1995 0:00:00  MARINE MISHAP         1.0       5.0
#              1/29/1993 0:00:00  HIGH WIND             0.0       1.0
#       1.0    10/27/1996 0:00:00 BLIZZARD              1.0       0.0
#              12/20/1996 0:00:00 HEAVY SNOW            0.0       2.0
# ...                                                   ...       ...
# WY    69.0   12/26/1998 0:00:00 ICY ROADS             1.0       1.0
#              12/9/1998 0:00:00  ICY ROADS             0.0       1.0
#              6/6/2007 0:00:00   HIGH WIND             0.0       1.0
#       70.0   12/20/2006 0:00:00 BLIZZARD              1.0       0.0
#       106.0  2/11/2011 0:00:00  HIGH WIND             1.0       0.0
#
# [21143 rows x 2 columns]

# %%
import datetime as dt

# %%
df4county['date'] = pd.to_datetime(df4county['BGN_DATE'])
df4county['year'] = df4county['date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-d04e470305c9> in <module>()
# ----> 1 df4county['date'] = pd.to_datetime(df4county['BGN_DATE'])
#       2 df4county['year'] = df4county['date'].dt.year
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
df4county
# Out:
#                                                FATALITIES  INJURIES
# STATE COUNTY BGN_DATE           EVTYPE
# AK    0.0    1/15/1995 0:00:00  MARINE MISHAP         6.0       0.0
#              1/27/1995 0:00:00  MARINE MISHAP         1.0       5.0
#              1/29/1993 0:00:00  HIGH WIND             0.0       1.0
#       1.0    10/27/1996 0:00:00 BLIZZARD              1.0       0.0
#              12/20/1996 0:00:00 HEAVY SNOW            0.0       2.0
# ...                                                   ...       ...
# WY    69.0   12/26/1998 0:00:00 ICY ROADS             1.0       1.0
#              12/9/1998 0:00:00  ICY ROADS             0.0       1.0
#              6/6/2007 0:00:00   HIGH WIND             0.0       1.0
#       70.0   12/20/2006 0:00:00 BLIZZARD              1.0       0.0
#       106.0  2/11/2011 0:00:00  HIGH WIND             1.0       0.0
#
# [21143 rows x 2 columns]
